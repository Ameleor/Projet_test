# %%
import os
import pandas as pd
import sys 
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
import re

# %%
# Read of our input files that have all the information collected about our genomes and the corresponding PGCfinder informations
df_brut = pd.read_csv('../results/lists_PGC/list_organisms_merged.csv')

# Read the csv already modified to have all the informations 
df_bryant= pd.read_csv('../data/supp_data_from_thiel_et_al_2018/table_3.tsv', sep='\t', header=0, na_values=['na'])
df_bryant_copy = df_bryant.copy()

df_all = pd.read_csv('../data/lists/list_with_taxonomy.csv', low_memory=False)

# %%
# Basic representation of our data
#df_brut.describe()

# Describe doesn't work with this df
df_bryant.describe()
# Out:
#        Unnamed: 9
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Creation of a clean dataframe
df_clean = df_brut.dropna(subset=['#Organism Name'])
#print(df_clean.describe())

# Creation of a PGC dataframe
df_PGC = df_clean[df_clean['number of genes'] > 24]
df_PGC.to_csv('../results/lists_PGC/list_organisms_merged_PGC.csv')
#print(df_PGC.describe())
df_PGC_alpha = df_PGC[df_PGC['Organism Groups'].str.contains('Alpha')]
df_PGC_beta = df_PGC[df_PGC['Organism Groups'].str.contains('Beta')]
df_PGC_gamma = df_PGC[df_PGC['Organism Groups'].str.contains('Gamma')]

df_PGC.describe()
# Out:
#          Size(Mb)         GC%   Scaffolds          CDS  number of PGC  \
# count  253.000000  253.000000  253.000000   253.000000          253.0
# mean     4.676585   63.623004    2.533597  4230.260870            1.0
# std      1.500391    8.205838    2.146393  1364.975912            0.0
# min      1.795160    0.000000    1.000000     0.000000            1.0
# 25%      3.669070   63.000000    1.000000  3341.000000            1.0
# 50%      4.425480   65.300000    1.000000  4127.000000            1.0
# 75%      5.599210   68.000000    3.000000  4929.000000            1.0
# max      8.493510   71.600000    9.000000  7530.000000            1.0
#
#        number of genes
# count       253.000000
# mean         31.158103
# std           1.500894
# min          25.000000
# 25%          31.000000
# 50%          31.000000
# 75%          32.000000
# max          34.000000

# %%
# Stats by Class
print("Informations nettoyé: \n", df_clean['Organism Groups'].value_counts(), "\n")
print("Informations PGC: \n", df_PGC['Organism Groups'].value_counts(), "\n")
print("Informations Bryant: \n", df_bryant['Taxonomy'].value_counts())
# Out:
# Informations nettoyé:
#  Organism Groups
# Bacteria;Pseudomonadota;Gammaproteobacteria    14900
# Bacteria;Pseudomonadota;Betaproteobacteria      2580
# Bacteria;Pseudomonadota;Alphaproteobacteria     2089
# Bacteria;Pseudomonadota;Acidithiobacillia         17
# Bacteria;Pseudomonadota;Zetaproteobacteria         2
# Bacteria;Pseudomonadota;Hydrogenophilia            1
# Name: count, dtype: int64
#
# Informations PGC:
#  Organism Groups
# Bacteria;Pseudomonadota;Alphaproteobacteria    209
# Bacteria;Pseudomonadota;Betaproteobacteria      30
# Bacteria;Pseudomonadota;Gammaproteobacteria     14
# Name: count, dtype: int64
#
# Informations Bryant:
#  Taxonomy
# Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae                                                      151
# Alphaproteobacteria; Sphingomonadales; Sphingomonadaceae                                                     79
# Alphaproteobacteria; Rhizobiales; Methylobacteriaceae                                                        72
# Alphaproteobacteria; Sphingomonadales; Erythrobacteraceae                                                    32
# Alphaproteobacteria; Rhizobiales; Bradyrhizobiaceae                                                          29
# Betaproteobacteria; Burkholderiales; Comamonadaceae                                                          26
# Alphaproteobacteria; Rhodospirillales; Rhodospirillaceae                                                     19
# Alphaproteobacteria; Rhodospirillales; Acetobacteraceae                                                      17
# Gammaproteobacteria; Chromatiales; Chromatiaceae                                                             16
# Gammaproteobacteria; Chromatiales; Ectothiorhodospiraceae                                                    13
# Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Rhizobium/Agrobacterium group                                 9
# Betaproteobacteria; Burkholderiales; unclassified Burkholderiales                                             9
# Alphaproteobacteria; Rhizobiales; Hyphomicrobiaceae                                                           8
# Betaproteobacteria; Nitrosomonadales; Sterolibacteriaceae                                                     7
# Betaproteobacteria; Burkholderiales; Burkholderiaceae                                                         6
# Alphaproteobacteria; Caulobacterales; Caulobacteraceae                                                        5
# Alphaproteobacteria; Rhizobiales; Aurantimonadaceae                                                           4
# Betaproteobacteria; Burkholderiales; unclassified Burkholderiales; Burkholderiales Genera incertae sedis      4
# Alphaproteobacteria; Rhizobiales; Phyllobacteriaceae                                                          4
# Betaproteobacteria; Burkholderiales; Comamonadaceae; Rhodoferax                                               3
# Alphaproteobacteria; Rhizobiales; Rhodobiaceae                                                                3
# Gammaproteobacteria; Cellvibrionales; Halieaceae; unclassified Halieaceae                                     3
# Alphaproteobacteria; Rhizobiales; Beijerinckiaceae                                                            3
# Alphaproteobacteria; Rhizobiales; Methylocystaceae                                                            2
# Alphaproteobacteria; unclassified Alphaproteobacteria                                                         1
# Alphaproteobacteria; Rhodospirillales; unclassified Rhodospirillales                                          1
# Alphaproteobacteria; Rhodospirillales; Rhodospirillaceae (uncertain)                                          1
# Gammaproteobacteria; Cellvibrionales; Halieaceae; Congregibacter                                              1
# Gammaproteobacteria; Cellvibrionales; Halieaceae; Luminiphilus                                                1
# Gammaproteobacteria; Cellvibrionales; Halieaceae; Pseudohaliea                                                1
# Gammaproteobacteria; Nevskiales; Sinobacteraceae                                                              1
# Name: count, dtype: int64

# %%
# Stats by Species
#print(df_clean['#Organism Name'].value_counts())
print(df_PGC['#Organism Name'].value_counts().head(5))
# Out:
# #Organism Name
# Rhodopseudomonas palustris    10
# Cereibacter sphaeroides        7
# Methylorubrum extorquens       6
# Bradyrhizobium cosmicum        2
# Rhodobacter capsulatus         2
# Name: count, dtype: int64

# %%
# Stats by Genus
genus_clean = df_clean.loc[:, 'Genus'] = df_clean.loc[:, '#Organism Name'].str.split().str[0]
genus_PGC = df_PGC.loc[:, 'Genus'] = df_PGC['#Organism Name'].str.split().str[0]
genus_bryant = df_bryant.loc[:, 'Genus'] = df_bryant['Organism_name'].str.split().str[0]

genus_clean_counts = genus_clean.value_counts().sort_index()
genus_PGC_counts = genus_PGC.value_counts().sort_index()
genus_bryant_counts = genus_bryant.value_counts().sort_index()

# Aligner les indices pour correspondre aux genres présents dans les deux séries
aligned_genus_clean_counts, aligned_genus_PGC_counts = genus_clean_counts.align(genus_PGC_counts, fill_value=0)


# Calculer les pourcentages de genus_PGC par rapport à genus_clean
genus_percentage = (aligned_genus_PGC_counts / aligned_genus_clean_counts) * 100

# Afficher les 20 premiers genres en termes de pourcentage
#print(genus_percentage.sort_values(ascending=False).head(93))

print(genus_bryant_counts)
# Out:
# Organism_name
# Acidiphilium       10
# Acidisphaera        1
# Aestuariivita       2
# Afifella            2
# Agrobacterium       3
#                    ..
# Tranquillimonas     1
# Variovorax          1
# gamma               1
# marine              2
# uncultured          2
# Name: count, Length: 130, dtype: int64
# /tmp/ipykernel_31033/4034465775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genus_clean = df_clean.loc[:, 'Genus'] = df_clean.loc[:, '#Organism Name'].str.split().str[0]
# /tmp/ipykernel_31033/4034465775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genus_PGC = df_PGC.loc[:, 'Genus'] = df_PGC['#Organism Name'].str.split().str[0]

# %%
print(genomes_list_PGC_alpha)
print(df_PGC_alpha["Assembly"])
# Out:
# ['GCF_000013365.1_ASM1336v1', 'GCF_003031265.1_ASM303126v1', 'GCF_000021745.1_ASM2174v1', 'GCF_000144605.1_ASM14460v1', 'GCF_000757795.1_ASM75779v1', 'GCF_000225955.1_ASM22595v1', 'GCF_009363795.1_ASM936379v1', 'GCF_029691625.1_ASM2969162v1', 'GCF_008932115.1_ASM893211v1', 'GCA_011765465.1_ASM1176546v1', 'GCF_003264115.1_ASM326411v1', 'GCF_007954425.1_ASM795442v1', 'GCF_001304795.1_ASM130479v1', 'GCF_000019725.1_ASM1972v1', 'GCF_026898155.1_ASM2689815v1', 'GCF_002002865.1_ASM200286v1', 'GCF_000015165.1_ASM1516v1', 'GCF_001720465.1_ASM172046v1', 'GCF_019203965.1_ASM1920396v1', 'GCF_000364445.2_ASM36444v2', 'GCF_009685175.1_ASM968517v1', 'GCF_023558355.1_ASM2355835v1', 'GCF_005860795.2_ASM586079v2', 'GCF_003324715.1_ASM332471v1', 'GCF_009363615.1_ASM936361v1', 'GCF_016584445.1_ASM1658444v1', 'GCF_003855495.1_ASM385549v1', 'GCF_003966715.1_ASM396671v1', 'GCF_014117445.1_ASM1411744v1', 'GCF_019431245.1_ASM1943124v1', 'GCF_002266435.2_ASM226643v2', 'GCF_001402875.1_ASM140287v1', 'GCF_000935025.1_ASM93502v1', 'GCF_022558965.1_ASM2255896v1', 'GCF_009363655.1_ASM936365v1', 'GCF_000018145.1_ASM1814v1', 'GCF_000019945.1_ASM1994v1', 'GCF_002355515.1_ASM235551v1', 'GCF_002983865.1_ASM298386v1', 'GCF_026625025.1_ASM2662502v1', 'GCF_000013565.1_ASM1356v1', 'GCF_000154785.2_ASM15478v2', 'GCF_022227035.1_ASM2222703v1', 'GCF_001854385.1_ASM185438v1', 'GCF_022410435.1_ASM2241043v1', 'GCF_024758725.1_ASM2475872v1', 'GCF_000016185.1_ASM1618v1', 'GCF_001685625.1_ASM168562v1', 'GCF_026167525.1_ASM2616752v1', 'GCF_012647365.1_ASM1264736v1', 'GCF_003173735.1_ASM317373v1', 'GCF_023380025.1_ASM2338002v1', 'GCF_014681765.1_ASM1468176v1', 'GCF_026167545.1_ASM2616754v1', 'GCF_009363575.1_ASM936357v1', 'GCF_004216475.1_ASM421647v1', 'GCF_023558335.1_ASM2355833v1', 'GCF_025917005.1_ASM2591700v1', 'GCF_001548075.1_ASM154807v1', 'GCF_025813715.1_ASM2581371v1', 'GCF_030252425.1_ASM3025242v1', 'GCF_027271155.1_ASM2727115v1', 'GCF_011040475.1_ASM1104047v1', 'GCF_001969365.1_ASM196936v1', 'GCF_001633145.1_ASM163314v1', 'GCF_002117815.2_ASM211781v2', 'GCF_029761955.1_ASM2976195v1', 'GCF_021088345.1_ASM2108834v1', 'GCF_009363715.1_ASM936371v1', 'GCF_000021845.1_ASM2184v1', 'GCF_005311585.1_ASM531158v1', 'GCF_003940805.1_ASM394080v1', 'GCF_009650195.1_ASM965019v1', 'GCF_001971665.1_ASM197166v1', 'GCF_003173715.1_ASM317371v1', 'GCF_003352165.1_ASM335216v1', 'GCF_000021865.1_ASM2186v1', 'GCF_001633165.1_ASM163316v1', 'GCF_011044255.1_ASM1104425v1', 'GCF_000738435.1_ASM73843v1', 'GCF_021117295.1_ASM2111729v1', 'GCF_008728195.1_ASM872819v1', 'GCF_028621955.1_ASM2862195v1', 'GCF_007290395.1_ASM729039v1', 'GCF_016839165.1_ASM1683916v1', 'GCF_021484845.1_ASM2148484v1', 'GCF_017498565.1_ASM1749856v1', 'GCF_021391315.1_ASM2139131v1', 'GCF_025811215.1_ASM2581121v1', 'GCF_024496245.1_ASM2449624v1', 'GCF_018200035.1_ASM1820003v1', 'GCF_003173775.1_ASM317377v1', 'GCF_019623905.1_ASM1962390v1', 'GCF_025811435.1_ASM2581143v1', 'GCF_000284275.1_ASM28427v1', 'GCF_025141175.1_ASM2514117v1', 'GCF_027886585.1_ASM2788658v1', 'GCF_026122615.1_ASM2612261v1', 'GCF_000021005.1_ASM2100v1', 'GCF_002158905.1_ASM215890v1', 'GCF_001713455.1_ASM171345v1', 'GCF_000018845.1_ASM1884v1', 'GCF_008843145.1_ASM884314v1', 'GCF_000512205.2_ASM51220v2', 'GCF_030062705.1_ASM3006270v1', 'GCF_003071405.1_ASM307140v1', 'GCF_023823125.1_ASM2382312v1', 'GCF_001548015.1_ASM154801v1', 'GCF_009913435.1_ASM991343v1', 'GCF_029277405.1_ASM2927740v1', 'GCF_022370455.1_ASM2237045v1', 'GCF_009707465.1_ASM970746v1', 'GCF_003254375.1_ASM325437v1', 'GCF_001713435.1_ASM171343v1', 'GCF_011047315.1_ASM1104731v1', 'GCF_013374095.1_ASM1337409v1', 'GCF_029714205.1_ASM2971420v1', 'GCF_002073975.1_ASM207397v1', 'GCF_001886735.1_ASM188673v1', 'GCF_000014045.1_ASM1404v1', 'GCF_021431965.1_ASM2143196v1', 'GCF_004354345.1_ASM435434v1', 'GCF_014495845.1_ASM1449584v1', 'GCF_000083545.1_ASM8354v1', 'GCF_000022685.1_ASM2268v1', 'GCF_007005445.1_ASM700544v1', 'GCF_014622665.1_ASM1462266v1', 'GCF_009762325.1_ASM976232v1', 'GCF_026122595.1_AS ...
# 0           000019725.1_ASM1972v1
# 2           000016185.1_ASM1618v1
# 3           000021005.1_ASM2100v1
# 5           000014045.1_ASM1404v1
# 130         000015165.1_ASM1516v1
#                    ...
# 17492    011047315.1_ASM1104731v1
# 17514    023380025.1_ASM2338002v1
# 17693     001663155.1_ASM166315v1
# 17694    015693905.1_ASM1569390v1
# 17737     009913435.1_ASM991343v1
# Name: Assembly, Length: 209, dtype: object

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

def analyse_genomes(genomes):
    # Récupération des profils de gènes
    PROFILES = [os.path.splitext(os.path.basename(gene))[0] for gene in glob.glob("../data/profiles/*.hmm")]

    # Dictionnaire pour stocker les DataFrames
    dfs = {}

    for genome in genomes:
        path = f"../results/genomes_PGC/{genome}/PGCfinder/best_solution.tsv"
        dfs[genome] = pd.read_csv(path, sep='\t', comment='#')

    # Dictionnaire pour stocker les occurrences de chaque gène
    gene_counts = {gene: 0 for gene in PROFILES}

    # Boucle à travers chaque génome
    for genome in genomes:
        # Charger le DataFrame pour le génome actuel
        df = dfs[genome]
        
        # Boucle à travers chaque profil de gène
        for gene in PROFILES:
            # Vérifier si le gène est présent dans le DataFrame
            if gene in df['gene_name'].values:
                # Incrémenter le compte pour le gène actuel
                gene_counts[gene] += 1

    # Calculer le nombre total de génomes
    total_genomes = len(genomes)

    # Calculer la fréquence de chaque gène
    gene_frequencies = {gene: (count / total_genomes) * 100 for gene, count in gene_counts.items()}

    # Trier les gènes par ordre alphabétique
    sorted_genes = sorted(gene_frequencies.keys())

    # Récupérer les fréquences triées selon les noms de gènes
    sorted_frequencies = [gene_frequencies[gene] for gene in sorted_genes]

    # Calculer les occurrences pour chaque gène trié
    occurrences = [gene_counts[gene] for gene in sorted_genes]

    # Créer un histogramme
    plt.figure(figsize=(10, 6))

    # Calcul des barres pour l'absence
    max_occurrences = max(occurrences)
    remaining = [max_occurrences - occ if occ < max_occurrences else 0 for occ in occurrences]
    
    # Ajouter les barres jaunes pour l'absence
    plt.bar(range(len(sorted_genes)), remaining, bottom=occurrences, color='gold', label=': absence')

    # Ajouter les barres bleues pour la présence
    plt.bar(range(len(sorted_genes)), occurrences, color='skyblue', label=': presence')

    # Ajouter les nombres d'occurrences au-dessus des barres
    for i, occ in enumerate(occurrences):
        plt.text(i, occ + 0.2, f'{round(occ)}', ha='center', rotation=45)

    # Ajouter la légende
    plt.legend()

    plt.xlabel('Gènes')
    plt.ylabel('Nombre d\'occurrences')
    plt.title('Nombre d\'occurrences des gènes dans les génomes (trié par nom de gène) \n')
    plt.xticks(range(len(sorted_genes)), sorted_genes, rotation=90)
    plt.tight_layout()
    plt.show()
    
# Exemple d'utilisation avec une liste de génomes
genomes_list_PGC_all = [os.path.basename(genome) for genome in glob.glob("../results/genomes_PGC/GC*")]
analyse_genomes(genomes_list_PGC_all)

# Cette étape est nécessaire car nos fichiers sont "GCF" ou "GCA" contrairement à notre colonne "Assembly" qui est uniquement en "GCA"
df_PGC_alpha.loc[:, 'Assembly'] = df_PGC_alpha['Assembly'].str.replace('GCA_', '')
df_PGC_beta.loc[:, 'Assembly'] = df_PGC_beta['Assembly'].str.replace('GCA_', '')
df_PGC_gamma.loc[:, 'Assembly'] = df_PGC_gamma['Assembly'].str.replace('GCA_', '')
df_PGC_alpha.loc[:, 'Assembly'] = df_PGC_alpha['Assembly'].str.replace('GCF_', '')
df_PGC_beta.loc[:, 'Assembly'] = df_PGC_beta['Assembly'].str.replace('GCF_', '')
df_PGC_gamma.loc[:, 'Assembly'] = df_PGC_gamma['Assembly'].str.replace('GCF_', '')

# Récupération des listes en utilisant les résultats partiels présent dans "Assembly" pour chaque df
genomes_list_PGC_alpha = [os.path.basename(genome) for genome in glob.glob("../results/genomes_PGC/GC*") if any(assembly_partial_alpha in os.path.basename(genome) for assembly_partial_alpha in df_PGC_alpha['Assembly'])]
genomes_list_PGC_beta = [os.path.basename(genome) for genome in glob.glob("../results/genomes_PGC/GC*") if any(assembly_partial in os.path.basename(genome) for assembly_partial in df_PGC_beta['Assembly'])]
genomes_list_PGC_gamma = [os.path.basename(genome) for genome in glob.glob("../results/genomes_PGC/GC*") if any(assembly_partial_gamma in os.path.basename(genome) for assembly_partial_gamma in df_PGC_gamma['Assembly'])]

# Pour faire fonctionner cette fonction il faut avoir au préalable un dataframe possèdant la colonne 'Assembly' avec dans les cases les noms partiels (ou entier) des fichiers que nous allons rechercher pour récupérer les différents gènes
# Ici je récupère un subset d'un dataframe propre avec comme condition le nom de la classe recherché (alpha, beta ou gamma). Nous pourrions tester sur le genre aussi par exemple (mais potentiel manque de données)
analyse_genomes(genomes_list_PGC_alpha)
analyse_genomes(genomes_list_PGC_beta)
analyse_genomes(genomes_list_PGC_gamma)

# %%
df_PGC_species = df_PGC.copy()
df_bryant_species = df_bryant_copy.copy()
PGC_species = df_PGC_species["#Organism Name"] = df_PGC_species["#Organism Name"].str.split().str[:2].str.join(' ')
bryant_species = df_bryant_species.iloc[:, 1]

genus_bryant = pd.Series(genus_bryant, name="Genus")
genus_PGC = pd.Series(genus_PGC, name="Genus")

print(genus_bryant.value_counts(), " \n \n ", genus_PGC.value_counts())
# Out:
# Genus
# Methylobacterium    72
# Sphingomonas        30
# Rhodobacter         26
# Blastomonas         23
# Porphyrobacter      20
#                     ..
# Roseomonas           1
# Acidisphaera         1
# Aurantimonas         1
# Tranquillimonas      1
# Nevskia              1
# Name: count, Length: 130, dtype: int64
#
#   Genus
# Methylobacterium        24
# Polynucleobacter        17
# Methylorubrum           15
# Rhodopseudomonas        13
# Sphingomonas            12
#                         ..
# Sphingosinicellaceae     1
# Aurantimonas             1
# Tateyamaria              1
# Peteryoungia             1
# Halorhodospira           1
# Name: count, Length: 92, dtype: int64

# %%
print("Informations nettoyé: \n", df_clean['Organism Groups'].value_counts(), "\n")
print("Informations PGC: \n", df_PGC['Organism Groups'].value_counts(), "\n")
# Out:
# Informations nettoyé:
#  Organism Groups
# Bacteria;Pseudomonadota;Gammaproteobacteria    14900
# Bacteria;Pseudomonadota;Betaproteobacteria      2580
# Bacteria;Pseudomonadota;Alphaproteobacteria     2089
# Bacteria;Pseudomonadota;Acidithiobacillia         17
# Bacteria;Pseudomonadota;Zetaproteobacteria         2
# Bacteria;Pseudomonadota;Hydrogenophilia            1
# Name: count, dtype: int64
#
# Informations PGC:
#  Organism Groups
# Bacteria;Pseudomonadota;Alphaproteobacteria    209
# Bacteria;Pseudomonadota;Betaproteobacteria      30
# Bacteria;Pseudomonadota;Gammaproteobacteria     14
# Name: count, dtype: int64

# %%
# Ajout de ces deux dataframe qui prennent en compte le nombre d'espèce et non de souche
df_PGC_species = df_PGC.drop_duplicates(subset=["species"])
df_clean_species = df_clean.drop_duplicates(subset=["species"])

# %%
unique_clean = df_clean['Genus'].unique()
unique_PGC = df_PGC['Genus'].unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'Genus' égale à i dans df_PGC
    PGC_count = df_PGC['Genus'].value_counts()[i]
    clean_count = df_clean['Genus'].value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['Genus', 'Percentage PGC/all', 'number of bacteria in the genus with PGC', 'number of bacteria']
df_stats_genus = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_genus_sorted = df_stats_genus.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_genus_sorted.to_csv("../results/stats/stats_by_genus.csv", index=False)

# %%
# Normalisé par le nombre d'espèce et non de souche
unique_clean = df_clean['Genus'].unique()
unique_PGC = df_PGC['Genus'].unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'Genus' égale à i dans df_PGC
    PGC_count = df_PGC_species['Genus'].value_counts()[i]
    clean_count = df_clean_species['Genus'].value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['Genus', 'Percentage PGC/all', 'number of bacteria in the genus with PGC', 'number of bacteria']
df_stats_genus = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_genus_sorted = df_stats_genus.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_genus_sorted.to_csv("../results/stats/normalize_by_species/stats_by_genus.csv", index=False)

# %%
unique_clean = df_clean['family'].dropna().unique()
unique_PGC = df_PGC['family'].dropna().unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_PGC
    PGC_count = df_PGC['family'].fillna(0).value_counts()[i]

    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_clean
    clean_count = df_clean['family'].fillna(0).value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100 if clean_count != 0 else 0

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['family', 'Percentage PGC/all', 'number of bacteria in the family with PGC', 'number of bacteria']
df_stats_family = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_family_sorted = df_stats_family.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_family_sorted.to_csv("../results/stats/stats_by_family.csv", index=False)

# %%
# Normalisée par le nombre d'espèce et non de souche
unique_clean = df_clean['family'].dropna().unique()
unique_PGC = df_PGC['family'].dropna().unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_PGC
    PGC_count = df_PGC_species['family'].fillna(0).value_counts()[i]

    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_clean
    clean_count = df_clean_species['family'].fillna(0).value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100 if clean_count != 0 else 0

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['family', 'Percentage PGC/all', 'number of bacteria in the family with PGC', 'number of bacteria']
df_stats_family = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_family_sorted = df_stats_family.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_family_sorted.to_csv("../results/stats/normalize_by_species/stats_by_family.csv", index=False)

# %%
unique_clean = df_clean['order'].dropna().unique()
unique_PGC = df_PGC['order'].dropna().unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_PGC
    PGC_count = df_PGC['order'].fillna(0).value_counts()[i]

    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_clean
    clean_count = df_clean['order'].fillna(0).value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100 if clean_count != 0 else 0

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['order', 'Percentage PGC/all', 'number of bacteria in the order with PGC', 'number of bacteria in']
df_stats_order = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_order_sorted = df_stats_order.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_order_sorted.to_csv("../results/stats/stats_by_order.csv", index=False)

# %%
# Normalisée par le nombre d'espèces et non de souches
unique_clean = df_clean['order'].dropna().unique()
unique_PGC = df_PGC['order'].dropna().unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_PGC
    PGC_count = df_PGC_species['order'].fillna(0).value_counts()[i]

    # Récupérer le nombre de valeurs de la colonne 'family' égale à i dans df_clean
    clean_count = df_clean_species['order'].fillna(0).value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100 if clean_count != 0 else 0

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['order', 'Percentage PGC/all', 'number of bacteria in the order with PGC', 'number of bacteria in']
df_stats_order = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_order_sorted = df_stats_order.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_order_sorted.to_csv("../results/stats/normalize_by_species/stats_by_order.csv", index=False)

# %%
unique_clean = df_clean['class'].dropna().unique()
unique_PGC = df_PGC['class'].dropna().unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'class' égale à i dans df_PGC
    PGC_count = df_PGC['class'].fillna(0).value_counts()[i]

    # Récupérer le nombre de valeurs de la colonne 'class' égale à i dans df_clean
    clean_count = df_clean['class'].fillna(0).value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100 if clean_count != 0 else 0

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['class', 'Percentage PGC/all', 'number of bacteria in the class with PGC', 'number of bacteria']
df_stats_class = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_class_sorted = df_stats_class.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_class_sorted.to_csv("../results/stats/stats_by_class.csv", index=False)

# %%
# Ici j'aimerais normalisée par l'espèce et non prendre en compte toutes les souches
unique_clean = df_clean['class'].dropna().unique()
unique_PGC = df_PGC['class'].dropna().unique()

# Créer une liste vide pour stocker les résultats
results = []

for i in unique_PGC:
    # Récupérer le nombre de valeurs de la colonne 'class' égale à i dans df_PGC
    PGC_count = df_PGC_species['class'].fillna(0).value_counts()[i]

    # Récupérer le nombre de valeurs de la colonne 'class' égale à i dans df_clean
    clean_count = df_clean_species['class'].fillna(0).value_counts()[i]

    # Calculer le pourcentage
    percentage = (PGC_count / clean_count) * 100 if clean_count != 0 else 0

    # Ajouter les résultats à la liste
    results.append([i, percentage, PGC_count, clean_count])

# Créer un nouveau DataFrame à partir des résultats
columns = ['class', 'Percentage PGC/all', 'number of bacteria in the class with PGC', 'number of bacteria']
df_stats_class = pd.DataFrame(results, columns=columns)

# Sort the DataFrame by the "Percentage PGC/all" column in descending order
df_stats_class_sorted = df_stats_class.sort_values(by='Percentage PGC/all', ascending=False).reset_index(drop=True)

# Write the sorted DataFrame to a CSV file without the index
df_stats_class_sorted.to_csv("../results/stats/normalize_by_species/stats_by_class.csv", index=False)

# %%
# Vérification de la localisation intra ou extra cluster de tspO, bchO, crtE, bchE

output_silix = pd.read_csv("../results/lists_PGC/output_silix_fullname_v1.csv")
unique_genome_silix = output_silix["genome"].dropna().unique()
numbers=[]

genes_of_interest = ["PGC_bchE"]
with_nearby_gene=0
without_nearby_gene=0

for genome in unique_genome_silix:
    # Filter the dataframe to only include rows where the genome column matches the current genome
    filtered_df = output_silix[(output_silix["genome"] == genome) & output_silix["hit_gene"].notna()]

    # Extract the prot_id_unique column from the filtered dataframe
    gene_number = filtered_df["prot_id_unique"]

    # Remove the prefix "genome_" from each element in the gene_number series
    gene_number = gene_number.str.replace(f"{genome}_", "", regex=False)

    # Convert the gene_number series to integers
    gene_number = gene_number.astype(int)

    # Search for the genes of interest in the filtered dataframe
    for gene in genes_of_interest:
        gene_match = filtered_df[filtered_df['hit_gene'] == gene]
        if not gene_match.empty:
            # Get the position of the gene
            gene_position = gene_match.iloc[0]['prot_id_unique']
            gene_position = int(gene_position.replace(f"{genome}_", ""))

            # Get the indices of the genes within the range of +5 to -5
            nearby_indices = (gene_number >= gene_position - 5) & (gene_number <= gene_position + 5)

            # Get the nearby genes
            nearby_genes = filtered_df[nearby_indices]

            # Remove the gene in question from the nearby genes
            nearby_genes = nearby_genes[nearby_genes['hit_gene'] != gene]

            # Print the nearby genes
            if not nearby_genes.empty:
                print(f"Gene {gene} found in genome {genome} at position {gene_position} with nearby genes:")
                print(nearby_genes[['hit_gene', 'prot_id_unique']])
                with_nearby_gene = with_nearby_gene + 1
            else:
                print(f"Gene {gene} found in genome {genome} at position {gene_position} with no nearby genes")
                without_nearby_gene = without_nearby_gene + 1
        #else:
            #print(f"Gene {gene} not found in genome {genome}")

print(without_nearby_gene)
print(with_nearby_gene)
# Out:
# Gene PGC_bchE found in genome GCF_017795885.1_ASM1779588v1 at position 905 with nearby genes:
#       hit_gene                    prot_id_unique
# 24    PGC_bchX  GCF_017795885.1_ASM1779588v1_907
# 25    PGC_bchC  GCF_017795885.1_ASM1779588v1_906
# 27    PGC_bchO  GCF_017795885.1_ASM1779588v1_903
# 28    PGC_bchD  GCF_017795885.1_ASM1779588v1_902
# 29    PGC_bchI  GCF_017795885.1_ASM1779588v1_901
# 3988  PGC_bchY  GCF_017795885.1_ASM1779588v1_908
# 6644  PGC_bchZ  GCF_017795885.1_ASM1779588v1_909
# Gene PGC_bchE found in genome GCF_009363495.1_ASM936349v1 at position 3648 with nearby genes:
#        hit_gene                    prot_id_unique
# 52     PGC_bchZ  GCF_009363495.1_ASM936349v1_3652
# 53     PGC_crtD  GCF_009363495.1_ASM936349v1_3646
# 54     PGC_tspO  GCF_009363495.1_ASM936349v1_3644
# 55     PGC_crtB  GCF_009363495.1_ASM936349v1_3643
# 7979   PGC_bchY  GCF_009363495.1_ASM936349v1_3651
# 8029   PGC_bchX  GCF_009363495.1_ASM936349v1_3650
# 9353   PGC_crtE  GCF_009363495.1_ASM936349v1_3647
# 9371   PGC_crtC  GCF_009363495.1_ASM936349v1_3645
# 12412  PGC_bchC  GCF_009363495.1_ASM936349v1_3649
# Gene PGC_bchE found in genome GCF_025811355.1_ASM2581135v1 at position 1498 with nearby genes:
#        hit_gene                     prot_id_unique
# 82     PGC_bchZ  GCF_025811355.1_ASM2581135v1_1502
# 83     PGC_bchC  GCF_025811355.1_ASM2581135v1_1499
# 85     PGC_crtC  GCF_025811355.1_ASM2581135v1_1495
# 2937   PGC_crtE  GCF_025811355.1_ASM2581135v1_1497
# 3012   PGC_crtD  GCF_025811355.1_ASM2581135v1_1496
# 11302  PGC_bchX  GCF_025811355.1_ASM2581135v1_1500
# 11320  PGC_bchY  GCF_025811355.1_ASM2581135v1_1501
# Gene PGC_bchE found in genome GCF_016806065.1_ASM1680606v1 at position 527 with nearby genes:
#        hit_gene                    prot_id_unique
# 110    PGC_bchC  GCF_016806065.1_ASM1680606v1_528
# 112    PGC_crtE  GCF_016806065.1_ASM1680606v1_526
# 114    PGC_crtB  GCF_016806065.1_ASM1680606v1_522
# 972    PGC_bchZ  GCF_016806065.1_ASM1680606v1_531
# 1552   PGC_crtD  GCF_016806065.1_ASM1680606v1_525
# 6138   PGC_bchY  GCF_016806065.1_ASM1680606v1_530
# 6952   PGC_bchX  GCF_016806065.1_ASM1680606v1_529
# 14038  PGC_crtC  GCF_016806065.1_ASM1680606v1_524
# Gene PGC_bchE found in genome GCF_001576595.1_ASM157659v1 at position 1903 with nearby genes:
#        hit_gene                    prot_id_unique
# 136    PGC_crtB  GCF_001576595.1_ASM157659v1_1908
# 138    PGC_bchX  GCF_001576595.1_ASM157659v1_1901
# 139    PGC_bchY  GCF_001576595.1_ASM157659v1_1900
# 140    PGC_bchZ  GCF_001576595.1_ASM157659v1_1899
# 1824   PGC_crtE  GCF_001576595.1_ASM157659v1_1904
# 2448   PGC_crtC  GCF_001576595.1_ASM157659v1_1906
# 11854  PGC_crtD  GCF_001576595.1_ASM157659v1_1905
# 13201  PGC_tspO  GCF_001576595.1_ASM157659v1_1907
# 14183  PGC_bchC  GCF_001576595.1_ASM157659v1_1902
# Gene PGC_bchE found in genome GCF_001936175.1_ASM193617v1 at position 2170 with nearby genes:
#        hit_gene                    prot_id_unique
# 281    PGC_crtD  GCF_001936175.1_ASM193617v1_2172
# 282    PGC_bchZ  GCF_001936175.1_ASM193617v1_2166
# 1481   PGC_bchC  GCF_001936175.1_ASM193617v1_2169
# 8210   PGC_crtE  GCF_001936175.1_ASM193617v1_2171
# 10004  PGC_bchY  GCF_001936175.1_ASM193617v1_2167
# 11973  PGC_crtC  GCF_001936175.1_ASM193617v1_2173
# 14576  PGC_bchX  GCF_001936175.1_ASM193617v1_2168
# Gene PGC_bchE found in genome GCF_000284255.1_ASM28425v1 at position 3328 with nearby genes:
#       hit_gene                   prot_id_unique
# 335   PGC_bchC  GCF_000284255.1_ASM28425v1_3327
# 336   PGC_bchX  GCF_000284255.1_ASM28425v1_3326
# 337   PGC_bchZ  GCF_000284255.1_ASM28425v1_3324
# 5258  PGC_bchY  GCF_000284255.1_ASM28425v1_3325
# 6677  PGC_crtE  GCF_000284255.1_ASM28425v1_3329
# Gene PGC_bchE found in genome GCF_001663155.1_ASM166315v1 at position 949 with nearby genes:
#       hit_gene                   prot_id_unique
# 529   PGC_bchZ  GCF_001663155.1_ASM166315v1_953
# 530   PGC_bchX  GCF_001663155.1_ASM166315v1_951
# 531   PGC_bchC  GCF_001663155.1_ASM166315v1_950
# 534   PGC_bchD  GCF_001663155.1_ASM166315v1_944
# 2045  PGC_bchO  GCF_001663155.1_ASM166315v1_945
# 6734  PGC_crtD  GCF_001663155.1_ASM166315v1_948
# 6995  PGC_crtC  GCF_001663155.1_ASM166315v1_947
# 7485  PGC_bchY  GCF_001663155.1_ASM166315v1_952
# Gene PGC_bchE found in genome GCF_016653635.2_ASM1665363v2 at position 3380 with nearby genes:
#        hit_gene                     prot_id_unique
# 559    PGC_crtB  GCF_016653635.2_ASM1665363v2_3385
# 561    PGC_crtC  GCF_016653635.2_ASM1665363v2_3383
# 563    PGC_bchX  GCF_016653635.2_ASM1665363v2_3378
# 564    PGC_bchY  GCF_016653635.2_ASM1665363v2_3377
# 565    PGC_bchZ  GCF_016653635.2_ASM1665363v2_3376
# 2122   PGC_crtE  GCF_016653635.2_ASM1665363v2_3381
# 5275   PGC_bchC  GCF_016653635.2_ASM1665363v2_3379
# 11312  PGC_crtD  GCF_016653635.2_ASM1665363v2_3382
# Gene PGC_bchE found in genome GCF_023243115.1_ASM2324311v1 at position 2736 with nearby genes:
#        hit_gene                     prot_id_unique
# 611    PGC_bchC  GCF_023243115.1_ASM2324311v1_2737
# 613    PGC_crtE  GCF_023243115.1_ASM2324311v1_2735
# 977    PGC_bchZ  GCF_023243115.1_ASM2324311v1_2740
# 1535   PGC_bchX  GCF_023243115.1_ASM2324311v1_2738
# 6757   PGC_crtC  GCF_023243115.1_ASM2324311v1_2734
# 12022  PGC_bchY  GCF_023243115.1_ASM2324311v1_2739
# Gene PGC_bchE found in genome GCF_001542815.1_ASM154281v1 at position 2565 with nearby genes:
#        hit_gene                    prot_id_unique
# 638    PGC_bchZ  GCF_001542815.1_ASM154281v1_2569
# 639    PGC_bchY  GCF_001542815.1_ASM154281v1_2568
# 640    PGC_bchX  GCF_001542815.1_ASM154281v1_2567
# 641    PGC_bchC  GCF_001542815.1_ASM154281v1_2566
# 642    PGC_crtC  GCF_001542815.1_ASM154281v1_2562
# 6722   PGC_crtE  GCF_001542815.1_ASM154281v1_2564
# 13040  PGC_crtD  GCF_001542815.1_ASM154281v1_2563
# Gene PGC_bchE found in genome GCF_013415845.1_ASM1341584v1 at position 1477 with nearby genes:
#        hit_gene                     prot_id_unique
# 660    PGC_crtE  GCF_013415845.1_ASM1341584v1_1476
# 1168   PGC_crtC  GCF_013415845.1_ASM1341584v1_1474
# 7960   PGC_crtD  GCF_013415845.1_ASM1341584v1_1475
# 8982   PGC_bchX  GCF_013415845.1_ASM1341584v1_1479
# 9886   PGC_bchC  GCF_013415845.1_ASM1341584v1_1478
# 11915  PGC_bchZ  GCF_013415845.1_ASM1341584v1_1481
# 13704  PGC_bchY  GCF_013415845.1_ASM1341584v1_1480
# Gene PGC_bchE found in genome GCF_004114955.1_ASM411495v1 at position 506 with nearby genes:
#        hit_gene                   prot_id_unique
# 692    PGC_bchC  GCF_004114955.1_ASM411495v1_507
# 694    PGC_crtE  GCF_004114955.1_ASM411495v1_505
# 695    PGC_crtD  GCF_004114955.1_ASM411495v1_504
# 696    PGC_crtC  GCF_004114955.1_ASM411495v1_503
# 3920   PGC_bchX  GCF_004114955.1_ASM411495v1_508
# 4468   PGC_crtB  GCF_004114955.1_ASM411495v1_501
# 11413  PGC_bchZ  GCF_004114955.1_ASM411495v1_510
# 14379  PGC_bchY  GCF_004114955.1_ASM411495v1_509
# Gene PGC_bchE found in genome GCF_030255395.1_ASM3025539v1 at position 2812 with nearby genes:
#       hit_gene                     prot_id_unique
# 739   PGC_bchZ  GCF_030255395.1_ASM3025539v1_2816
# 740   PGC_bchY  GCF_030255395.1_ASM3025539v1_2815
# 741   PGC_bchX  GCF_030255395.1_ASM3025539v1_2814
# 742   PGC_crtD  GCF_030255395.1_ASM3025539v1_2810
# 3313  PGC_crtE  GCF_030255395.1_ASM3025539v1_2811
# 5300  PGC_crtC  GCF_030255395.1_ASM3025539v1_2809
# 9964  PGC_bchC  GCF_030255395.1_ASM3025539v1_2813
# Gene PGC_bchE found in genome GCF_000344805.1_ASM34480v1 at position 5863 with nearby genes:
#        hit_gene                   prot_id_unique
# 760    PGC_crtB  GCF_000344805.1_ASM34480v1_5868
# 761    PGC_crtC  GCF_000344805.1_ASM34480v1_5866
# 762    PGC_crtE  GCF_000344805.1_ASM34480v1_5864
# 763    PGC_bchC  GCF_000344805.1_ASM34480v1_5862
# 764    PGC_bchX  GCF_000344805.1_ASM34480v1_5861
# 765    PGC_bchY  GCF_000344805.1_ASM34480v1_5860
# 766    PGC_bchZ  GCF_000344805.1_ASM34480v1_5859
# 10130  PGC_crtD  GCF_000344805.1_ASM34480v1_5865
# Gene PGC_bchE found in genome GCF_015679265.1_ASM1567926v1 at position 3 with nearby genes:
#        hit_gene                  prot_id_unique
# 937    PGC_crtB  GCF_015679265.1_ASM1567926v1_8
# 938    PGC_tspO  GCF_015679265.1_ASM1567926v1_7
# 939    PGC_crtC  GCF_015679265.1_ASM1567926v1_6
# 940    PGC_bchC  GCF_015679265.1_ASM1567926v1_2
# 941    PGC_bchX  GCF_015679265.1_ASM1567926v1_1
# 3370   PGC_crtD  GCF_015679265.1_ASM1567926v1_5
# 14796  PGC_crtE  GCF_015679265.1_ASM1567926v1_4
# Gene PGC_bchE found in genome GCA_015693905.1_ASM1569390v1 at position 1843 with nearby genes:
#        hit_gene                     prot_id_unique
# 959    PGC_bchC  GCA_015693905.1_ASM1569390v1_1844
# 961    PGC_crtE  GCA_015693905.1_ASM1569390v1_1842
# 1539   PGC_bchY  GCA_015693905.1_ASM1569390v1_1846
# 2900   PGC_bchX  GCA_015693905.1_ASM1569390v1_1845
# 3430   PGC_crtC  GCA_015693905.1_ASM1569390v1_1840
# 3956   PGC_bchZ  GCA_015693905.1_ASM1569390v1_1847
# 11245  PGC_crtD  GCA_015693905.1_ASM1569390v1_1841
# Gene PGC_bchE found in genome GCF_019443285.1_ASM1944328v1 at position 1079 with nearby genes:
#        hit_gene                     prot_id_unique
# 998    PGC_crtD  GCF_019443285.1_ASM1944328v1_1078
# 999    PGC_crtC  GCF_019443285.1_ASM1944328v1_1077
# 1000   PGC_bchO  GCF_019443285.1_ASM1944328v1_1075
# 5542   PGC_bchY  GCF_019443285.1_ASM1944328v1_1082
# 8207   PGC_bchC  GCF_019443285.1_ASM1944328v1_1080
# 8438   PGC_bchZ  GCF_019443285.1_ASM1944328v1_1083
# 10789  PGC_bchX  GCF_019443285.1_ASM1944328v1_1081
# 10945  PGC_bchD  GCF_019443285.1_ASM1944328v1_1074
# Gene PGC_bchE found in genome GCF_011388215.1_ASM1138821v1 at position 23 with nearby genes:
#        hit_gene                   prot_id_unique
# 1093   PGC_bchY  GCF_011388215.1_ASM1138821v1_26
# 1094   PGC_bchX  GCF_011388215.1_ASM1138821v1_25
# 1095   PGC_crtC  GCF_011388215.1_ASM1138821v1_20
# 1097   PGC_crtB  GCF_011388215.1_ASM1138821v1_18
# 6623   PGC_crtE  GCF_011388215.1_ASM1138821v1_22
# 8084   PGC_crtD  GCF_011388215.1_ASM1138821v1_21
# 9356   PGC_bchZ  GCF_011388215.1_ASM1138821v1_27
# 15016  PGC_bchC  GCF_011388215.1_ASM1138821v1_24
# Gene PGC_bchE found in genome GCA_016745215.1_scaff03 at position 2463 with nearby genes:
#       hit_gene                prot_id_unique
# 1160  PGC_bchC  GCA_016745215.1_scaff03_2464
# 1950  PGC_bchX  GCA_016745215.1_scaff03_2465
# 2170  PGC_bchZ  GCA_016745215.1_scaff03_2467
# 2422  PGC_bchY  GCA_016745215.1_scaff03_2466
# 9592  PGC_crtE  GCA_016745215.1_scaff03_2462
# Gene PGC_bchE found in genome GCF_017347565.1_ASM1734756v1 at position 889 with nearby genes:
#        hit_gene                    prot_id_unique
# 1191   PGC_crtE  GCF_017347565.1_ASM1734756v1_888
# 1192   PGC_crtD  GCF_017347565.1_ASM1734756v1_887
# 1193   PGC_crtC  GCF_017347565.1_ASM1734756v1_886
# 3432   PGC_bchC  GCF_017347565.1_ASM1734756v1_890
# 5639   PGC_bchZ  GCF_017347565.1_ASM1734756v1_893
# 5866   PGC_bchY  GCF_017347565.1_ASM1734756v1_892
# 13507  PGC_bchX  GCF_017347565.1_ASM1734756v1_891
# Gene PGC_bchE found in genome GCF_018982885.2_ASM1898288v2 at position 3377 with nearby genes:
#        hit_gene                     prot_id_unique
# 1227   PGC_bchI  GCF_018982885.2_ASM1898288v2_3382
# 1228   PGC_bchD  GCF_018982885.2_ASM1898288v2_3381
# 1229   PGC_bchO  GCF_018982885.2_ASM1898288v2_3380
# 1230   PGC_crtC  GCF_018982885.2_ASM1898288v2_3379
# 1232   PGC_bchZ  GCF_018982885.2_ASM1898288v2_3373
# 1978   PGC_bchY  GCF_018982885.2_ASM1898288v2_3374
# 3125   PGC_bchC  GCF_018982885.2_ASM1898288v2_3376
# 9105   PGC_crtD  GCF_018982885.2_ASM1898288v2_3378
# 10937  PGC_bchX  GCF_018982885.2_ASM1898288v2_3375
# Gene PGC_bchE found in genome GCF_030297615.1_ASM3029761v1 at position 1475 with nearby genes:
#        hit_gene                     prot_id_unique
# 1286   PGC_bchI  GCF_030297615.1_ASM3029761v1_1479
# 1287   PGC_bchD  GCF_030297615.1_ASM3029761v1_1478
# 1288   PGC_bchY  GCF_030297615.1_ASM3029761v1_1472
# 1435   PGC_bchO  GCF_030297615.1_ASM3029761v1_1477
# 2271   PGC_bchZ  GCF_030297615.1_ASM3029761v1_1471
# 4282   PGC_bchC  GCF_030297615.1_ASM3029761v1_1474
# 6410   PGC_bchX  GCF_030297615.1_ASM3029761v1_1473
# 13630  PGC_crtE  GCF_030297615.1_ASM3029761v1_1476
# Gene PGC_bchE found in genome GCF_000020445.1_ASM2044v1 at position 1703 with nearby genes:
#        hit_gene                  prot_id_unique
# 1339   PGC_bchY  GCF_000020445.1_ASM2044v1_1706
# 1342   PGC_bchX  GCF_000020445.1_ASM2044v1_1705
# 1343   PGC_crtE  GCF_000020445.1_ASM2044v1_1702
# 5817   PGC_crtC  GCF_000020445.1_ASM2044v1_1700
# 6372   PGC_bchC  GCF_000020445.1_ASM2044v1_1704
# 9302   PGC_bchZ  GCF_000020445.1_ASM2044v1_1707
# 11293  PGC_crtD  GCF_000020445.1_ASM2044v1_1701
# Gene PGC_bchE found in genome GCF_012932215.1_ASM1293221v1 at position 3703 with nearby genes:
#        hit_gene                     prot_id_unique
# 1382   PGC_bchZ  GCF_012932215.1_ASM1293221v1_3708
# 1385   PGC_crtE  GCF_012932215.1_ASM1293221v1_3702
# 1386   PGC_crtD  GCF_012932215.1_ASM1293221v1_3701
# 1387   PGC_crtC  GCF_012932215.1_ASM1293221v1_3700
# 4696   PGC_bchX  GCF_012932215.1_ASM1293221v1_3705
# 5962   PGC_bchC  GCF_012932215.1_ASM1293221v1_3704
# 8674   PGC_tspO  GCF_012932215.1_ASM1293221v1_3698
# 10085  PGC_bchY  GCF_012932215.1_ASM1293221v1_3707
# Gene PGC_bchE found in genome GCF_009363635.1_ASM936363v1 at position 2713 with nearby genes:
#       hit_gene                    prot_id_unique
# 1426  PGC_bchZ  GCF_009363635.1_ASM936363v1_2717
# 1427  PGC_bchY  GCF_009363635.1_ASM936363v1_2716
# 1428  PGC_bchX  GCF_009363635.1_ASM936363v1_2715
# 1429  PGC_bchC  GCF_009363635.1_ASM936363v1_2714
# 1431  PGC_crtD  GCF_009363635.1_ASM936363v1_2712
# 1432  PGC_crtC  GCF_009363635.1_ASM936363v1_2711
# 1436  PGC_bchO  GCF_009363635.1_ASM936363v1_2709
# 9734  PGC_bchD  GCF_009363635.1_ASM936363v1_2708
# Gene PGC_bchE found in genome GCF_000166055.1_ASM16605v1 at position 208 with nearby genes:
#       hit_gene                  prot_id_unique
# 1475  PGC_bchZ  GCF_000166055.1_ASM16605v1_212
# 1476  PGC_bchY  GCF_000166055.1_ASM16605v1_211
# 1477  PGC_bchC  GCF_000166055.1_ASM16605v1_209
# 1478  PGC_crtD  GCF_000166055.1_ASM16605v1_207
# 3402  PGC_crtC  GCF_000166055.1_ASM16605v1_206
# 5251  PGC_bchX  GCF_000166055.1_ASM16605v1_210
# Gene PGC_bchE found in genome GCF_001412535.1_ASM141253v1 at position 616 with nearby genes:
#       hit_gene                   prot_id_unique
# 1517  PGC_bchZ  GCF_001412535.1_ASM141253v1_620
# 1518  PGC_bchY  GCF_001412535.1_ASM141253v1_619
# 1519  PGC_bchC  GCF_001412535.1_ASM141253v1_617
# 7767  PGC_bchX  GCF_001412535.1_ASM141253v1_618
# 8403  PGC_crtE  GCF_001412535.1_ASM141253v1_615
# Gene PGC_bchE found in genome GCF_020866845.1_ASM2086684v1 at position 2396 with nearby genes:
#        hit_gene                     prot_id_unique
# 1614   PGC_bchX  GCF_020866845.1_ASM2086684v1_2398
# 1615   PGC_bchC  GCF_020866845.1_ASM2086684v1_2397
# 1616   PGC_crtD  GCF_020866845.1_ASM2086684v1_2395
# 1617   PGC_crtC  GCF_020866845.1_ASM2086684v1_2394
# 1618   PGC_bchO  GCF_020866845.1_ASM2086684v1_2392
# 2801   PGC_bchD  GCF_020866845.1_ASM2086684v1_2391
# 7073   PGC_bchZ  GCF_020866845.1_ASM2086684v1_2400
# 11328  PGC_bchY  GCF_020866845.1_ASM2086684v1_2399
# Gene PGC_bchE found in genome GCF_018688155.1_ASM1868815v1 at position 1362 with nearby genes:
#        hit_gene                     prot_id_unique
# 1749   PGC_bchD  GCF_018688155.1_ASM1868815v1_1366
# 1750   PGC_bchI  GCF_018688155.1_ASM1868815v1_1365
# 1751   PGC_crtE  GCF_018688155.1_ASM1868815v1_1363
# 2943   PGC_bchO  GCF_018688155.1_ASM1868815v1_1367
# 6156   PGC_bchY  GCF_018688155.1_ASM1868815v1_1359
# 6767   PGC_bchC  GCF_018688155.1_ASM1868815v1_1361
# 7719   PGC_bchH  GCF_018688155.1_ASM1868815v1_1364
# 8453   PGC_bchX  GCF_018688155.1_ASM1868815v1_1360
# 11900  PGC_bchZ  GCF_018688155.1_ASM1868815v1_1358
# Gene PGC_bchE found in genome GCF_002813775.1_ASM281377v1 at position 6235 with no nearby genes
# Gene PGC_bchE found in genome GCF_021391535.1_ASM2139153v1 at position 1270 with nearby genes:
#        hit_gene                     prot_id_unique
# 1884   PGC_bchO  GCF_021391535.1_ASM2139153v1_1274
# 1885   PGC_tspO  GCF_021391535.1_ASM2139153v1_1273
# 1886   PGC_crtC  GCF_021391535.1_ASM2139153v1_1272
# 1887   PGC_crtD  GCF_021391535.1_ASM2139153v1_1271
# 1889   PGC_bchC  GCF_021391535.1_ASM2139153v1_1269
# 1890   PGC_bchX  GCF_021391535.1_ASM2139153v1_1268
# 1891   PGC_bchY  GCF_021391535.1_ASM2139153v1_1267
# 1893   PGC_bchZ  GCF_021391535.1_ASM2139153v1_1266
# 14083  PGC_bchD  GCF_021391535.1_ASM2139153v1_1275
# Gene PGC_bchE found in genome GCF_006542605.1_ASM654260v1 at position 1474 with nearby genes:
#        hit_gene                    prot_id_unique
# 2075   PGC_bchX  GCF_006542605.1_ASM654260v1_1472
# 2076   PGC_bchZ  GCF_006542605.1_ASM654260v1_1470
# 3236   PGC_bchY  GCF_006542605.1_ASM654260v1_1471
# 4347   PGC_crtD  GCF_006542605.1_ASM654260v1_1475
# 14050  PGC_bchC  GCF_006542605.1_ASM654260v1_1473
# 14245  PGC_crtC  GCF_006542605.1_ASM654260v1_1476
# Gene PGC_bchE found in genome GCF_027944005.1_ASM2794400v1 at position 1946 with nearby genes:
#        hit_gene                     prot_id_unique
# 2103   PGC_bchD  GCF_027944005.1_ASM2794400v1_1949
# 2106   PGC_bchZ  GCF_027944005.1_ASM2794400v1_1942
# 6703   PGC_bchI  GCF_027944005.1_ASM2794400v1_1950
# 7590   PGC_bchC  GCF_027944005.1_ASM2794400v1_1945
# 13255  PGC_crtE  GCF_027944005.1_ASM2794400v1_1947
# 14487  PGC_bchY  GCF_027944005.1_ASM2794400v1_1943
# 15177  PGC_bchX  GCF_027944005.1_ASM2794400v1_1944
# Gene PGC_bchE found in genome GCF_028885395.1_ASM2888539v1 at position 1429 with nearby genes:
#        hit_gene                     prot_id_unique
# 2209   PGC_bchY  GCF_028885395.1_ASM2888539v1_1433
# 2212   PGC_crtE  GCF_028885395.1_ASM2888539v1_1428
# 2213   PGC_crtC  GCF_028885395.1_ASM2888539v1_1426
# 3140   PGC_bchZ  GCF_028885395.1_ASM2888539v1_1434
# 5896   PGC_bchX  GCF_028885395.1_ASM2888539v1_1431
# 6214   PGC_crtD  GCF_028885395.1_ASM2888539v1_1427
# 10230  PGC_bchC  GCF_028885395.1_ASM2888539v1_1430
# Gene PGC_bchE found in genome GCF_001713475.1_ASM171347v1 at position 3607 with nearby genes:
#       hit_gene                    prot_id_unique
# 2225  PGC_crtD  GCF_001713475.1_ASM171347v1_3609
# 2227  PGC_bchC  GCF_001713475.1_ASM171347v1_3606
# 2228  PGC_bchY  GCF_001713475.1_ASM171347v1_3604
# 2229  PGC_bchZ  GCF_001713475.1_ASM171347v1_3603
# 2583  PGC_crtB  GCF_001713475.1_ASM171347v1_3612
# 5302  PGC_crtC  GCF_001713475.1_ASM171347v1_3610
# 5417  PGC_bchX  GCF_001713475.1_ASM171347v1_3605
# 5928  PGC_crtE  GCF_001713475.1_ASM171347v1_3608
# Gene PGC_bchE found in genome GCF_021228795.1_ASM2122879v1 at position 1775 with nearby genes:
#       hit_gene                     prot_id_unique
# 2330  PGC_crtC  GCF_021228795.1_ASM2122879v1_1778
# 2331  PGC_crtD  GCF_021228795.1_ASM2122879v1_1777
# 2332  PGC_crtE  GCF_021228795.1_ASM2122879v1_1776
# 2334  PGC_bchC  GCF_021228795.1_ASM2122879v1_1774
# 2335  PGC_bchX  GCF_021228795.1_ASM2122879v1_1773
# 2336  PGC_bchZ  GCF_021228795.1_ASM2122879v1_1771
# 2957  PGC_bchY  GCF_021228795.1_ASM2122879v1_1772
# Gene PGC_bchE found in genome GCF_021228015.1_ASM2122801v1 at position 4204 with nearby genes:
#        hit_gene                     prot_id_unique
# 2344   PGC_crtD  GCF_021228015.1_ASM2122801v1_4206
# 2346   PGC_crtE  GCF_021228015.1_ASM2122801v1_4205
# 2348   PGC_bchC  GCF_021228015.1_ASM2122801v1_4203
# 2349   PGC_bchY  GCF_021228015.1_ASM2122801v1_4201
# 2351   PGC_bchZ  GCF_021228015.1_ASM2122801v1_4200
# 6279   PGC_crtC  GCF_021228015.1_ASM2122801v1_4207
# 12741  PGC_bchX  GCF_021228015.1_ASM2122801v1_4202
# Gene PGC_bchE found in genome GCF_003173755.1_ASM317375v1 at position 989 with nearby genes:
#        hit_gene                   prot_id_unique
# 2484   PGC_bchX  GCF_003173755.1_ASM317375v1_991
# 2485   PGC_crtE  GCF_003173755.1_ASM317375v1_988
# 4073   PGC_crtD  GCF_003173755.1_ASM317375v1_987
# 4387   PGC_bchC  GCF_003173755.1_ASM317375v1_990
# 12132  PGC_bchY  GCF_003173755.1_ASM317375v1_992
# 13366  PGC_bchZ  GCF_003173755.1_ASM317375v1_993
# 14356  PGC_crtC  GCF_003173755.1_ASM317375v1_986
# Gene PGC_bchE found in genome GCF_016765655.2_ASM1676565v2 at position 1745 with nearby genes:
#        hit_gene                     prot_id_unique
# 2508   PGC_bchX  GCF_016765655.2_ASM1676565v2_1747
# 2509   PGC_bchC  GCF_016765655.2_ASM1676565v2_1746
# 2511   PGC_crtE  GCF_016765655.2_ASM1676565v2_1744
# 2512   PGC_crtD  GCF_016765655.2_ASM1676565v2_1743
# 2513   PGC_crtC  GCF_016765655.2_ASM1676565v2_1742
# 3134   PGC_crtB  GCF_016765655.2_ASM1676565v2_1740
# 6765   PGC_bchZ  GCF_016765655.2_ASM1676565v2_1749
# 11748  PGC_bchY  GCF_016765655.2_ASM1676565v2_1748
# Gene PGC_bchE found in genome GCF_003288315.1_ASM328831v1 at position 3700 with nearby genes:
#       hit_gene                    prot_id_unique
# 2564  PGC_crtD  GCF_003288315.1_ASM328831v1_3702
# 2566  PGC_crtE  GCF_003288315.1_ASM328831v1_3701
# 2568  PGC_bchC  GCF_003288315.1_ASM328831v1_3699
# 2570  PGC_bchX  GCF_003288315.1_ASM328831v1_3698
# 2571  PGC_bchY  GCF_003288315.1_ASM328831v1_3696
# 2572  PGC_bchZ  GCF_003288315.1_ASM328831v1_3695
# 7099  PGC_crtC  GCF_003288315.1_ASM328831v1_3703
# Gene PGC_bchE found in genome GCF_023573145.1_ASM2357314v1 at position 504 with nearby genes:
#        hit_gene                    prot_id_unique
# 2816   PGC_crtC  GCF_023573145.1_ASM2357314v1_507
# 2817   PGC_crtD  GCF_023573145.1_ASM2357314v1_506
# 2818   PGC_bchX  GCF_023573145.1_ASM2357314v1_502
# 4605   PGC_crtE  GCF_023573145.1_ASM2357314v1_505
# 5035   PGC_bchC  GCF_023573145.1_ASM2357314v1_503
# 5093   PGC_bchZ  GCF_023573145.1_ASM2357314v1_500
# 11776  PGC_bchY  GCF_023573145.1_ASM2357314v1_501
# Gene PGC_bchE found in genome GCF_008000895.1_ASM800089v1 at position 2927 with nearby genes:
#        hit_gene                    prot_id_unique
# 2838   PGC_crtC  GCF_008000895.1_ASM800089v1_2930
# 2839   PGC_crtD  GCF_008000895.1_ASM800089v1_2929
# 2840   PGC_crtE  GCF_008000895.1_ASM800089v1_2928
# 2841   PGC_bchC  GCF_008000895.1_ASM800089v1_2926
# 2842   PGC_bchX  GCF_008000895.1_ASM800089v1_2925
# 2843   PGC_bchZ  GCF_008000895.1_ASM800089v1_2923
# 12349  PGC_bchY  GCF_008000895.1_ASM800089v1_2924
# Gene PGC_bchE found in genome GCF_000021845.1_ASM2184v1 at position 2932 with nearby genes:
#        hit_gene                  prot_id_unique
# 2969   PGC_bchY  GCF_000021845.1_ASM2184v1_2935
# 2992   PGC_bchZ  GCF_000021845.1_ASM2184v1_2936
# 3351   PGC_crtE  GCF_000021845.1_ASM2184v1_2931
# 3669   PGC_bchX  GCF_000021845.1_ASM2184v1_2934
# 6781   PGC_crtC  GCF_000021845.1_ASM2184v1_2929
# 8598   PGC_bchC  GCF_000021845.1_ASM2184v1_2933
# 10338  PGC_crtD  GCF_000021845.1_ASM2184v1_2930
# Gene PGC_bchE found in genome GCF_002117815.2_ASM211781v2 at position 4190 with nearby genes:
#        hit_gene                    prot_id_unique
# 3443   PGC_bchX  GCF_002117815.2_ASM211781v2_4192
# 5720   PGC_crtD  GCF_002117815.2_ASM211781v2_4188
# 6639   PGC_bchZ  GCF_002117815.2_ASM211781v2_4194
# 7514   PGC_bchC  GCF_002117815.2_ASM211781v2_4191
# 8503   PGC_bchY  GCF_002117815.2_ASM211781v2_4193
# 14387  PGC_crtC  GCF_002117815.2_ASM211781v2_4187
# 14866  PGC_crtE  GCF_002117815.2_ASM211781v2_4189
# Gene PGC_bchE found in genome GCF_009762325.1_ASM976232v1 at position 1024 with nearby genes:
#        hit_gene                    prot_id_unique
# 3316   PGC_crtE  GCF_009762325.1_ASM976232v1_1023
# 9055   PGC_crtD  GCF_009762325.1_ASM976232v1_1022
# 10037  PGC_bchZ  GCF_009762325.1_ASM976232v1_1028
# 13217  PGC_tspO  GCF_009762325.1_ASM976232v1_1020
# 14546  PGC_crtB  GCF_009762325.1_ASM976232v1_1019
# 14547  PGC_crtC  GCF_009762325.1_ASM976232v1_1021
# 14549  PGC_bchC  GCF_009762325.1_ASM976232v1_1025
# 14551  PGC_bchX  GCF_009762325.1_ASM976232v1_1026
# 14554  PGC_bchY  GCF_009762325.1_ASM976232v1_1027
# Gene PGC_bchE found in genome GCF_002266435.2_ASM226643v2 at position 4750 with nearby genes:
#        hit_gene                    prot_id_unique
# 7045   PGC_crtC  GCF_002266435.2_ASM226643v2_4753
# 7903   PGC_crtD  GCF_002266435.2_ASM226643v2_4752
# 8149   PGC_bchY  GCF_002266435.2_ASM226643v2_4747
# 9281   PGC_crtE  GCF_002266435.2_ASM226643v2_4751
# 10231  PGC_bchZ  GCF_002266435.2_ASM226643v2_4746
# 10233  PGC_bchX  GCF_002266435.2_ASM226643v2_4748
# 12481  PGC_bchC  GCF_002266435.2_ASM226643v2_4749
# Gene PGC_bchE found in genome GCF_023823125.1_ASM2382312v1 at position 2746 with nearby genes:
#        hit_gene                     prot_id_unique
# 6269   PGC_bchO  GCF_023823125.1_ASM2382312v1_2742
# 8215   PGC_bchZ  GCF_023823125.1_ASM2382312v1_2750
# 8381   PGC_bchC  GCF_023823125.1_ASM2382312v1_2747
# 8872   PGC_crtC  GCF_023823125.1_ASM2382312v1_2744
# 12910  PGC_crtD  GCF_023823125.1_ASM2382312v1_2745
# 13093  PGC_bchD  GCF_023823125.1_ASM2382312v1_2741
# 13097  PGC_bchX  GCF_023823125.1_ASM2382312v1_2748
# 13099  PGC_bchY  GCF_023823125.1_ASM2382312v1_2749
# Gene PGC_bchE found in genome GCF_025811435.1_ASM2581143v1 at position 1574 with nearby genes:
#        hit_gene                     prot_id_unique
# 5474   PGC_bchY  GCF_025811435.1_ASM2581143v1_1577
# 7069   PGC_bchZ  GCF_025811435.1_ASM2581143v1_1578
# 12199  PGC_crtD  GCF_025811435.1_ASM2581143v1_1572
# 12205  PGC_bchC  GCF_025811435.1_ASM2581143v1_1575
# 12206  PGC_bchX  GCF_025811435.1_ASM2581143v1_1576
# 12495  PGC_crtC  GCF_025811435.1_ASM2581143v1_1571
# 13843  PGC_crtE  GCF_025811435.1_ASM2581143v1_1573
# Gene PGC_bchE found in genome GCF_007005445.1_ASM700544v1 at position 695 with nearby genes:
#        hit_gene                   prot_id_unique
# 2989   PGC_bchC  GCF_007005445.1_ASM700544v1_696
# 3565   PGC_bchZ  GCF_007005445.1_ASM700544v1_699
# 8364   PGC_bchX  GCF_007005445.1_ASM700544v1_697
# 10588  PGC_crtC  GCF_007005445.1_ASM700544v1_692
# 12802  PGC_crtD  GCF_007005445.1_ASM700544v1_693
# 14477  PGC_crtE  GCF_007005445.1_ASM700544v1_694
# 14479  PGC_bchY  GCF_007005445.1_ASM700544v1_698
# Gene PGC_bchE found in genome GCF_009363795.1_ASM936379v1 at position 2700 with nearby genes:
#        hit_gene                    prot_id_unique
# 6887   PGC_crtE  GCF_009363795.1_ASM936379v1_2701
# 6903   PGC_bchZ  GCF_009363795.1_ASM936379v1_2696
# 7310   PGC_bchC  GCF_009363795.1_ASM936379v1_2699
# 8580   PGC_crtD  GCF_009363795.1_ASM936379v1_2702
# 9662   PGC_crtC  GCF_009363795.1_ASM936379v1_2703
# 11404  PGC_bchX  GCF_009363795.1_ASM936379v1_2698
# 13213  PGC_bchY  GCF_009363795.1_ASM936379v1_2697
# Gene PGC_bchE found in genome GCF_003065365.1_ASM306536v1 at position 383 with nearby genes:
#        hit_gene                   prot_id_unique
# 3400   PGC_bchD  GCF_003065365.1_ASM306536v1_379
# 5065   PGC_bchX  GCF_003065365.1_ASM306536v1_385
# 9958   PGC_bchO  GCF_003065365.1_ASM306536v1_381
# 10521  PGC_crtE  GCF_003065365.1_ASM306536v1_382
# 11184  PGC_bchI  GCF_003065365.1_ASM306536v1_378
# 11185  PGC_bchC  GCF_003065365.1_ASM306536v1_384
# 11189  PGC_bchY  GCF_003065365.1_ASM306536v1_386
# 13128  PGC_bchZ  GCF_003065365.1_ASM306536v1_387
# Gene PGC_bchE found in genome GCF_025398155.2_ASM2539815v2 at position 239 with nearby genes:
#        hit_gene                    prot_id_unique
# 5339   PGC_bchY  GCF_025398155.2_ASM2539815v2_242
# 5343   PGC_bchX  GCF_025398155.2_ASM2539815v2_241
# 5350   PGC_crtE  GCF_025398155.2_ASM2539815v2_238
# 5351   PGC_crtC  GCF_025398155.2_ASM2539815v2_236
# 7663   PGC_bchC  GCF_025398155.2_ASM2539815v2_240
# 9432   PGC_crtD  GCF_025398155.2_ASM2539815v2_237
# 15182  PGC_bchZ  GCF_025398155.2_ASM2539815v2_243
# Gene PGC_bchE found in genome GCF_000013365.1_ASM1336v1 at position 4065 with nearby genes:
#        hit_gene                  prot_id_unique
# 5735   PGC_crtC  GCF_000013365.1_ASM1336v1_4068
# 6583   PGC_bchX  GCF_000013365.1_ASM1336v1_4063
# 7154   PGC_bchZ  GCF_000013365.1_ASM1336v1_4061
# 7242   PGC_crtE  GCF_000013365.1_ASM1336v1_4066
# 7379   PGC_crtD  GCF_000013365.1_ASM1336v1_4067
# 7386   PGC_bchC  GCF_000013365.1_ASM1336v1_4064
# 12722  PGC_bchY  GCF_000013365.1_ASM1336v1_4062
# Gene PGC_bchE found in genome GCF_003855495.1_ASM385549v1 at position 3365 with nearby genes:
#        hit_gene                    prot_id_unique
# 6806   PGC_crtB  GCF_003855495.1_ASM385549v1_3360
# 8073   PGC_bchZ  GCF_003855495.1_ASM385549v1_3369
# 8905   PGC_bchX  GCF_003855495.1_ASM385549v1_3367
# 9121   PGC_crtE  GCF_003855495.1_ASM385549v1_3364
# 9864   PGC_bchY  GCF_003855495.1_ASM385549v1_3368
# 9879   PGC_crtD  GCF_003855495.1_ASM385549v1_3363
# 11982  PGC_bchC  GCF_003855495.1_ASM385549v1_3366
# 13450  PGC_crtC  GCF_003855495.1_ASM385549v1_3362
# Gene PGC_bchE found in genome GCF_003264115.1_ASM326411v1 at position 2736 with nearby genes:
#        hit_gene                    prot_id_unique
# 3304   PGC_bchX  GCF_003264115.1_ASM326411v1_2738
# 6130   PGC_bchZ  GCF_003264115.1_ASM326411v1_2740
# 6143   PGC_crtC  GCF_003264115.1_ASM326411v1_2734
# 6153   PGC_bchO  GCF_003264115.1_ASM326411v1_2732
# 8583   PGC_bchC  GCF_003264115.1_ASM326411v1_2737
# 9143   PGC_bchD  GCF_003264115.1_ASM326411v1_2731
# 9196   PGC_bchY  GCF_003264115.1_ASM326411v1_2739
# 11058  PGC_crtD  GCF_003264115.1_ASM326411v1_2735
# Gene PGC_bchE found in genome GCF_004136295.1_ASM413629v1 at position 721 with nearby genes:
#        hit_gene                   prot_id_unique
# 6029   PGC_crtE  GCF_004136295.1_ASM413629v1_722
# 6685   PGC_bchY  GCF_004136295.1_ASM413629v1_718
# 7981   PGC_crtB  GCF_004136295.1_ASM413629v1_726
# 8211   PGC_bchZ  GCF_004136295.1_ASM413629v1_717
# 8625   PGC_crtD  GCF_004136295.1_ASM413629v1_723
# 9967   PGC_bchX  GCF_004136295.1_ASM413629v1_719
# 10442  PGC_bchC  GCF_004136295.1_ASM413629v1_720
# 12995  PGC_crtC  GCF_004136295.1_ASM413629v1_724
# Gene PGC_bchE found in genome GCF_001483865.1_ASM148386v1 at position 1029 with nearby genes:
#        hit_gene                    prot_id_unique
# 3856   PGC_crtE  GCF_001483865.1_ASM148386v1_1028
# 3857   PGC_crtC  GCF_001483865.1_ASM148386v1_1026
# 4356   PGC_crtD  GCF_001483865.1_ASM148386v1_1027
# 4953   PGC_bchC  GCF_001483865.1_ASM148386v1_1030
# 9217   PGC_bchY  GCF_001483865.1_ASM148386v1_1032
# 12365  PGC_bchX  GCF_001483865.1_ASM148386v1_1031
# Gene PGC_bchE found in genome GCF_001870665.2_ASM187066v2 at position 600 with nearby genes:
#        hit_gene                   prot_id_unique
# 5781   PGC_crtE  GCF_001870665.2_ASM187066v2_599
# 7520   PGC_bchC  GCF_001870665.2_ASM187066v2_601
# 7542   PGC_bchZ  GCF_001870665.2_ASM187066v2_604
# 8032   PGC_bchY  GCF_001870665.2_ASM187066v2_603
# 11283  PGC_bchO  GCF_001870665.2_ASM187066v2_596
# 11637  PGC_crtC  GCF_001870665.2_ASM187066v2_597
# 14742  PGC_bchD  GCF_001870665.2_ASM187066v2_595
# 14744  PGC_crtD  GCF_001870665.2_ASM187066v2_598
# 14746  PGC_bchX  GCF_001870665.2_ASM187066v2_602
# Gene PGC_bchE found in genome GCF_013170845.1_ASM1317084v1 at position 6024 with nearby genes:
#        hit_gene                     prot_id_unique
# 7437   PGC_crtC  GCF_013170845.1_ASM1317084v1_6028
# 9609   PGC_bchX  GCF_013170845.1_ASM1317084v1_6022
# 9846   PGC_crtD  GCF_013170845.1_ASM1317084v1_6027
# 10009  PGC_crtE  GCF_013170845.1_ASM1317084v1_6025
# 10345  PGC_bchZ  GCF_013170845.1_ASM1317084v1_6020
# 12274  PGC_bchC  GCF_013170845.1_ASM1317084v1_6023
# 13158  PGC_bchY  GCF_013170845.1_ASM1317084v1_6021
# Gene PGC_bchE found in genome GCF_021484845.1_ASM2148484v1 at position 2918 with nearby genes:
#        hit_gene                     prot_id_unique
# 7800   PGC_crtE  GCF_021484845.1_ASM2148484v1_2919
# 8604   PGC_bchX  GCF_021484845.1_ASM2148484v1_2916
# 8649   PGC_bchC  GCF_021484845.1_ASM2148484v1_2917
# 11668  PGC_bchZ  GCF_021484845.1_ASM2148484v1_2914
# 11669  PGC_bchY  GCF_021484845.1_ASM2148484v1_2915
# 11672  PGC_crtD  GCF_021484845.1_ASM2148484v1_2920
# 11673  PGC_crtC  GCF_021484845.1_ASM2148484v1_2921
# Gene PGC_bchE found in genome GCF_000284275.1_ASM28427v1 at position 1886 with nearby genes:
#        hit_gene                   prot_id_unique
# 3040   PGC_crtD  GCF_000284275.1_ASM28427v1_1884
# 3476   PGC_crtE  GCF_000284275.1_ASM28427v1_1885
# 3755   PGC_bchZ  GCF_000284275.1_ASM28427v1_1890
# 6951   PGC_bchY  GCF_000284275.1_ASM28427v1_1889
# 12263  PGC_crtC  GCF_000284275.1_ASM28427v1_1883
# 12267  PGC_bchC  GCF_000284275.1_ASM28427v1_1887
# 12269  PGC_bchX  GCF_000284275.1_ASM28427v1_1888
# Gene PGC_bchE found in genome GCF_013378075.1_ASM1337807v1 at position 1366 with nearby genes:
#        hit_gene                     prot_id_unique
# 9260   PGC_bchX  GCF_013378075.1_ASM1337807v1_1364
# 10024  PGC_bchC  GCF_013378075.1_ASM1337807v1_1365
# 13968  PGC_bchI  GCF_013378075.1_ASM1337807v1_1371
# 14801  PGC_bchZ  GCF_013378075.1_ASM1337807v1_1362
# 14802  PGC_bchY  GCF_013378075.1_ASM1337807v1_1363
# 14804  PGC_crtD  GCF_013378075.1_ASM1337807v1_1367
# 14805  PGC_crtC  GCF_013378075.1_ASM1337807v1_1368
# 14808  PGC_bchO  GCF_013378075.1_ASM1337807v1_1369
# 14810  PGC_bchD  GCF_013378075.1_ASM1337807v1_1370
# Gene PGC_bchE found in genome GCF_001713375.1_ASM171337v1 at position 1387 with nearby genes:
#        hit_gene                    prot_id_unique
# 6427   PGC_bchC  GCF_001713375.1_ASM171337v1_1386
# 10433  PGC_bchZ  GCF_001713375.1_ASM171337v1_1383
# 10435  PGC_bchY  GCF_001713375.1_ASM171337v1_1384
# 10436  PGC_bchX  GCF_001713375.1_ASM171337v1_1385
# 10441  PGC_crtE  GCF_001713375.1_ASM171337v1_1388
# Gene PGC_bchE found in genome GCF_016584445.1_ASM1658444v1 at position 1540 with nearby genes:
#       hit_gene                     prot_id_unique
# 3788  PGC_bchC  GCF_016584445.1_ASM1658444v1_1541
# 8822  PGC_bchZ  GCF_016584445.1_ASM1658444v1_1544
# 9811  PGC_crtC  GCF_016584445.1_ASM1658444v1_1537
# 9813  PGC_crtD  GCF_016584445.1_ASM1658444v1_1538
# 9824  PGC_bchX  GCF_016584445.1_ASM1658444v1_1542
# 9827  PGC_bchY  GCF_016584445.1_ASM1658444v1_1543
# 9838  PGC_crtE  GCF_016584445.1_ASM1658444v1_1539
# Gene PGC_bchE found in genome GCF_003352165.1_ASM335216v1 at position 3123 with nearby genes:
#        hit_gene                    prot_id_unique
# 4434   PGC_crtC  GCF_003352165.1_ASM335216v1_3126
# 5795   PGC_bchZ  GCF_003352165.1_ASM335216v1_3119
# 10879  PGC_bchY  GCF_003352165.1_ASM335216v1_3120
# 10881  PGC_bchX  GCF_003352165.1_ASM335216v1_3121
# 10887  PGC_crtD  GCF_003352165.1_ASM335216v1_3125
# 13455  PGC_bchC  GCF_003352165.1_ASM335216v1_3122
# 14765  PGC_crtE  GCF_003352165.1_ASM335216v1_3124
# Gene PGC_bchE found in genome GCF_000512205.2_ASM51220v2 at position 3617 with nearby genes:
#        hit_gene                   prot_id_unique
# 3650   PGC_bchC  GCF_000512205.2_ASM51220v2_3616
# 4378   PGC_bchD  GCF_000512205.2_ASM51220v2_3622
# 4587   PGC_bchY  GCF_000512205.2_ASM51220v2_3614
# 7963   PGC_crtC  GCF_000512205.2_ASM51220v2_3619
# 10681  PGC_bchX  GCF_000512205.2_ASM51220v2_3615
# 12943  PGC_bchZ  GCF_000512205.2_ASM51220v2_3613
# 12944  PGC_crtD  GCF_000512205.2_ASM51220v2_3618
# 12947  PGC_bchO  GCF_000512205.2_ASM51220v2_3621
# Gene PGC_bchE found in genome GCF_009913435.1_ASM991343v1 at position 2330 with nearby genes:
#        hit_gene                    prot_id_unique
# 3735   PGC_bchX  GCF_009913435.1_ASM991343v1_2328
# 4097   PGC_bchY  GCF_009913435.1_ASM991343v1_2327
# 11004  PGC_bchZ  GCF_009913435.1_ASM991343v1_2326
# 13238  PGC_bchC  GCF_009913435.1_ASM991343v1_2329
# 13240  PGC_crtD  GCF_009913435.1_ASM991343v1_2331
# 13243  PGC_bchO  GCF_009913435.1_ASM991343v1_2334
# Gene PGC_bchE found in genome GCF_029761955.1_ASM2976195v1 at position 5813 with nearby genes:
#       hit_gene                     prot_id_unique
# 3082  PGC_crtE  GCF_029761955.1_ASM2976195v1_5812
# 3442  PGC_bchX  GCF_029761955.1_ASM2976195v1_5815
# 4346  PGC_bchY  GCF_029761955.1_ASM2976195v1_5816
# 5767  PGC_bchZ  GCF_029761955.1_ASM2976195v1_5817
# 6919  PGC_crtD  GCF_029761955.1_ASM2976195v1_5811
# 7120  PGC_crtC  GCF_029761955.1_ASM2976195v1_5810
# 8444  PGC_bchC  GCF_029761955.1_ASM2976195v1_5814
# Gene PGC_bchE found in genome GCF_022558965.1_ASM2255896v1 at position 2447 with nearby genes:
#        hit_gene                     prot_id_unique
# 3302   PGC_crtB  GCF_022558965.1_ASM2255896v1_2442
# 5483   PGC_bchY  GCF_022558965.1_ASM2255896v1_2450
# 6103   PGC_bchC  GCF_022558965.1_ASM2255896v1_2448
# 6325   PGC_crtD  GCF_022558965.1_ASM2255896v1_2445
# 7306   PGC_bchX  GCF_022558965.1_ASM2255896v1_2449
# 8069   PGC_crtE  GCF_022558965.1_ASM2255896v1_2446
# 9205   PGC_bchZ  GCF_022558965.1_ASM2255896v1_2451
# 11593  PGC_crtC  GCF_022558965.1_ASM2255896v1_2444
# Gene PGC_bchE found in genome GCF_024758725.1_ASM2475872v1 at position 1643 with nearby genes:
#        hit_gene                     prot_id_unique
# 3475   PGC_bchY  GCF_024758725.1_ASM2475872v1_1640
# 4359   PGC_bchO  GCF_024758725.1_ASM2475872v1_1648
# 4365   PGC_crtD  GCF_024758725.1_ASM2475872v1_1644
# 5626   PGC_bchC  GCF_024758725.1_ASM2475872v1_1642
# 6273   PGC_bchZ  GCF_024758725.1_ASM2475872v1_1639
# 8028   PGC_bchX  GCF_024758725.1_ASM2475872v1_1641
# 13772  PGC_crtC  GCF_024758725.1_ASM2475872v1_1645
# Gene PGC_bchE found in genome GCF_000144605.1_ASM14460v1 at position 3041 with nearby genes:
#        hit_gene                   prot_id_unique
# 4975   PGC_bchX  GCF_000144605.1_ASM14460v1_3039
# 5814   PGC_bchD  GCF_000144605.1_ASM14460v1_3046
# 6193   PGC_bchY  GCF_000144605.1_ASM14460v1_3038
# 7135   PGC_crtC  GCF_000144605.1_ASM14460v1_3043
# 7666   PGC_crtD  GCF_000144605.1_ASM14460v1_3042
# 8238   PGC_bchO  GCF_000144605.1_ASM14460v1_3044
# 8567   PGC_bchZ  GCF_000144605.1_ASM14460v1_3037
# 14384  PGC_bchC  GCF_000144605.1_ASM14460v1_3040
# Gene PGC_bchE found in genome GCF_021117295.1_ASM2111729v1 at position 2687 with nearby genes:
#        hit_gene                     prot_id_unique
# 3846   PGC_crtD  GCF_021117295.1_ASM2111729v1_2685
# 5145   PGC_bchY  GCF_021117295.1_ASM2111729v1_2690
# 10252  PGC_bchX  GCF_021117295.1_ASM2111729v1_2689
# 11225  PGC_crtC  GCF_021117295.1_ASM2111729v1_2684
# 11226  PGC_crtE  GCF_021117295.1_ASM2111729v1_2686
# 11231  PGC_bchC  GCF_021117295.1_ASM2111729v1_2688
# 11233  PGC_bchZ  GCF_021117295.1_ASM2111729v1_2691
# Gene PGC_bchE found in genome GCF_000018845.1_ASM1884v1 at position 2808 with nearby genes:
#        hit_gene                  prot_id_unique
# 9060   PGC_crtC  GCF_000018845.1_ASM1884v1_2805
# 11623  PGC_bchX  GCF_000018845.1_ASM1884v1_2810
# 12306  PGC_crtE  GCF_000018845.1_ASM1884v1_2807
# 12754  PGC_crtD  GCF_000018845.1_ASM1884v1_2806
# 12756  PGC_bchC  GCF_000018845.1_ASM1884v1_2809
# 12757  PGC_bchY  GCF_000018845.1_ASM1884v1_2811
# 12759  PGC_bchZ  GCF_000018845.1_ASM1884v1_2812
# Gene PGC_bchE found in genome GCF_008843145.1_ASM884314v1 at position 1695 with nearby genes:
#        hit_gene                    prot_id_unique
# 3100   PGC_crtB  GCF_008843145.1_ASM884314v1_1690
# 5101   PGC_crtE  GCF_008843145.1_ASM884314v1_1694
# 5809   PGC_crtD  GCF_008843145.1_ASM884314v1_1693
# 6229   PGC_bchC  GCF_008843145.1_ASM884314v1_1696
# 8370   PGC_crtC  GCF_008843145.1_ASM884314v1_1692
# 12854  PGC_bchX  GCF_008843145.1_ASM884314v1_1697
# 12855  PGC_bchY  GCF_008843145.1_ASM884314v1_1698
# 12860  PGC_bchZ  GCF_008843145.1_ASM884314v1_1699
# Gene PGC_bchE found in genome GCF_007290395.1_ASM729039v1 at position 1479 with nearby genes:
#        hit_gene                    prot_id_unique
# 3111   PGC_bchX  GCF_007290395.1_ASM729039v1_1477
# 3423   PGC_bchZ  GCF_007290395.1_ASM729039v1_1475
# 4593   PGC_bchY  GCF_007290395.1_ASM729039v1_1476
# 7911   PGC_bchC  GCF_007290395.1_ASM729039v1_1478
# 8584   PGC_crtE  GCF_007290395.1_ASM729039v1_1480
# 11497  PGC_crtD  GCF_007290395.1_ASM729039v1_1481
# 11500  PGC_crtC  GCF_007290395.1_ASM729039v1_1482
# Gene PGC_bchE found in genome GCF_002355515.1_ASM235551v1 at position 2969 with nearby genes:
#        hit_gene                    prot_id_unique
# 5126   PGC_bchZ  GCF_002355515.1_ASM235551v1_2973
# 5137   PGC_bchX  GCF_002355515.1_ASM235551v1_2971
# 5141   PGC_crtE  GCF_002355515.1_ASM235551v1_2968
# 5147   PGC_crtD  GCF_002355515.1_ASM235551v1_2967
# 9207   PGC_bchC  GCF_002355515.1_ASM235551v1_2970
# 11920  PGC_crtC  GCF_002355515.1_ASM235551v1_2966
# 12939  PGC_bchY  GCF_002355515.1_ASM235551v1_2972
# Gene PGC_bchE found in genome GCA_011765465.1_ASM1176546v1 at position 235 with nearby genes:
#        hit_gene                    prot_id_unique
# 6213   PGC_bchO  GCA_011765465.1_ASM1176546v1_239
# 6221   PGC_crtD  GCA_011765465.1_ASM1176546v1_236
# 6223   PGC_bchC  GCA_011765465.1_ASM1176546v1_234
# 6482   PGC_bchD  GCA_011765465.1_ASM1176546v1_240
# 7311   PGC_bchX  GCA_011765465.1_ASM1176546v1_233
# 8420   PGC_bchY  GCA_011765465.1_ASM1176546v1_232
# 9698   PGC_crtC  GCA_011765465.1_ASM1176546v1_237
# 11692  PGC_bchZ  GCA_011765465.1_ASM1176546v1_231
# Gene PGC_bchE found in genome GCF_026122615.1_ASM2612261v1 at position 3847 with nearby genes:
#        hit_gene                     prot_id_unique
# 10493  PGC_bchX  GCF_026122615.1_ASM2612261v1_3845
# 11486  PGC_crtC  GCF_026122615.1_ASM2612261v1_3850
# 12517  PGC_bchZ  GCF_026122615.1_ASM2612261v1_3843
# 12521  PGC_bchY  GCF_026122615.1_ASM2612261v1_3844
# 12525  PGC_crtE  GCF_026122615.1_ASM2612261v1_3848
# 12528  PGC_crtD  GCF_026122615.1_ASM2612261v1_3849
# 12835  PGC_bchC  GCF_026122615.1_ASM2612261v1_3846
# Gene PGC_bchE found in genome GCF_001633145.1_ASM163314v1 at position 878 with nearby genes:
#        hit_gene                   prot_id_unique
# 3166   PGC_bchZ  GCF_001633145.1_ASM163314v1_883
# 3167   PGC_crtD  GCF_001633145.1_ASM163314v1_876
# 5004   PGC_crtC  GCF_001633145.1_ASM163314v1_875
# 9069   PGC_bchX  GCF_001633145.1_ASM163314v1_880
# 9412   PGC_crtE  GCF_001633145.1_ASM163314v1_877
# 9913   PGC_bchC  GCF_001633145.1_ASM163314v1_879
# 12551  PGC_bchY  GCF_001633145.1_ASM163314v1_882
# Gene PGC_bchE found in genome GCF_001713435.1_ASM171343v1 at position 3529 with nearby genes:
#        hit_gene                    prot_id_unique
# 6733   PGC_bchC  GCF_001713435.1_ASM171343v1_3530
# 8349   PGC_bchY  GCF_001713435.1_ASM171343v1_3532
# 13271  PGC_bchD  GCF_001713435.1_ASM171343v1_3527
# 13629  PGC_bchI  GCF_001713435.1_ASM171343v1_3526
# 13631  PGC_bchO  GCF_001713435.1_ASM171343v1_3528
# 13634  PGC_bchX  GCF_001713435.1_ASM171343v1_3531
# 13635  PGC_bchZ  GCF_001713435.1_ASM171343v1_3533
# Gene PGC_bchE found in genome GCF_001713455.1_ASM171345v1 at position 4035 with nearby genes:
#        hit_gene                    prot_id_unique
# 3147   PGC_crtB  GCF_001713455.1_ASM171345v1_4040
# 3258   PGC_crtE  GCF_001713455.1_ASM171345v1_4036
# 12735  PGC_bchZ  GCF_001713455.1_ASM171345v1_4031
# 12737  PGC_bchY  GCF_001713455.1_ASM171345v1_4032
# 12738  PGC_bchX  GCF_001713455.1_ASM171345v1_4033
# 12740  PGC_bchC  GCF_001713455.1_ASM171345v1_4034
# 12743  PGC_crtD  GCF_001713455.1_ASM171345v1_4037
# 12745  PGC_crtC  GCF_001713455.1_ASM171345v1_4038
# Gene PGC_bchE found in genome GCF_008932115.1_ASM893211v1 at position 4868 with nearby genes:
#        hit_gene                    prot_id_unique
# 6373   PGC_bchX  GCF_008932115.1_ASM893211v1_4870
# 6375   PGC_crtC  GCF_008932115.1_ASM893211v1_4865
# 6407   PGC_crtE  GCF_008932115.1_ASM893211v1_4867
# 7969   PGC_bchC  GCF_008932115.1_ASM893211v1_4869
# 8307   PGC_crtD  GCF_008932115.1_ASM893211v1_4866
# 10051  PGC_bchY  GCF_008932115.1_ASM893211v1_4871
# 11858  PGC_bchZ  GCF_008932115.1_ASM893211v1_4872
# Gene PGC_bchE found in genome GCF_000021745.1_ASM2174v1 at position 2051 with nearby genes:
#        hit_gene                  prot_id_unique
# 5499   PGC_crtD  GCF_000021745.1_ASM2174v1_2049
# 6642   PGC_crtE  GCF_000021745.1_ASM2174v1_2050
# 6723   PGC_bchC  GCF_000021745.1_ASM2174v1_2052
# 7106   PGC_bchZ  GCF_000021745.1_ASM2174v1_2055
# 8046   PGC_ppsR  GCF_000021745.1_ASM2174v1_2047
# 8288   PGC_crtC  GCF_000021745.1_ASM2174v1_2048
# 8572   PGC_bchY  GCF_000021745.1_ASM2174v1_2054
# 15111  PGC_bchX  GCF_000021745.1_ASM2174v1_2053
# Gene PGC_bchE found in genome GCF_021431965.1_ASM2143196v1 at position 94 with nearby genes:
#        hit_gene                   prot_id_unique
# 3223   PGC_bchD  GCF_021431965.1_ASM2143196v1_99
# 4609   PGC_bchZ  GCF_021431965.1_ASM2143196v1_90
# 7569   PGC_bchC  GCF_021431965.1_ASM2143196v1_93
# 10178  PGC_crtC  GCF_021431965.1_ASM2143196v1_96
# 13124  PGC_bchX  GCF_021431965.1_ASM2143196v1_92
# 13474  PGC_crtD  GCF_021431965.1_ASM2143196v1_95
# 14118  PGC_bchY  GCF_021431965.1_ASM2143196v1_91
# 14123  PGC_bchO  GCF_021431965.1_ASM2143196v1_98
# Gene PGC_bchE found in genome GCF_026167545.1_ASM2616754v1 at position 27 with nearby genes:
#        hit_gene                   prot_id_unique
# 3705   PGC_bchX  GCF_026167545.1_ASM2616754v1_29
# 3710   PGC_bchD  GCF_026167545.1_ASM2616754v1_22
# 4204   PGC_bchO  GCF_026167545.1_ASM2616754v1_23
# 4309   PGC_crtD  GCF_026167545.1_ASM2616754v1_26
# 7058   PGC_bchZ  GCF_026167545.1_ASM2616754v1_31
# 8797   PGC_crtC  GCF_026167545.1_ASM2616754v1_25
# 10042  PGC_bchY  GCF_026167545.1_ASM2616754v1_30
# 13101  PGC_bchC  GCF_026167545.1_ASM2616754v1_28
# Gene PGC_bchE found in genome GCF_000225955.1_ASM22595v1 at position 3030 with nearby genes:
#        hit_gene                   prot_id_unique
# 3184   PGC_crtC  GCF_000225955.1_ASM22595v1_3033
# 6118   PGC_bchY  GCF_000225955.1_ASM22595v1_3027
# 7662   PGC_crtD  GCF_000225955.1_ASM22595v1_3032
# 7975   PGC_bchX  GCF_000225955.1_ASM22595v1_3028
# 8309   PGC_bchC  GCF_000225955.1_ASM22595v1_3029
# 8323   PGC_crtE  GCF_000225955.1_ASM22595v1_3031
# 12471  PGC_bchZ  GCF_000225955.1_ASM22595v1_3026
# Gene PGC_bchE found in genome GCF_027912195.1_ASM2791219v1 at position 1504 with nearby genes:
#        hit_gene                     prot_id_unique
# 5804   PGC_crtD  GCF_027912195.1_ASM2791219v1_1502
# 7385   PGC_crtE  GCF_027912195.1_ASM2791219v1_1503
# 9408   PGC_bchZ  GCF_027912195.1_ASM2791219v1_1508
# 13080  PGC_bchX  GCF_027912195.1_ASM2791219v1_1506
# 14685  PGC_crtC  GCF_027912195.1_ASM2791219v1_1501
# 14687  PGC_bchC  GCF_027912195.1_ASM2791219v1_1505
# 14692  PGC_bchY  GCF_027912195.1_ASM2791219v1_1507
# Gene PGC_bchE found in genome GCF_021391315.1_ASM2139131v1 at position 1798 with nearby genes:
#        hit_gene                     prot_id_unique
# 3279   PGC_bchZ  GCF_021391315.1_ASM2139131v1_1794
# 7968   PGC_bchY  GCF_021391315.1_ASM2139131v1_1795
# 11769  PGC_crtC  GCF_021391315.1_ASM2139131v1_1801
# 11817  PGC_bchX  GCF_021391315.1_ASM2139131v1_1796
# 11821  PGC_crtE  GCF_021391315.1_ASM2139131v1_1799
# 11825  PGC_crtD  GCF_021391315.1_ASM2139131v1_1800
# 13727  PGC_bchC  GCF_021391315.1_ASM2139131v1_1797
# Gene PGC_bchE found in genome GCF_011040475.1_ASM1104047v1 at position 2343 with nearby genes:
#        hit_gene                     prot_id_unique
# 3237   PGC_bchC  GCF_011040475.1_ASM1104047v1_2342
# 3837   PGC_crtC  GCF_011040475.1_ASM1104047v1_2346
# 3919   PGC_bchX  GCF_011040475.1_ASM1104047v1_2341
# 4656   PGC_bchY  GCF_011040475.1_ASM1104047v1_2340
# 7677   PGC_crtD  GCF_011040475.1_ASM1104047v1_2345
# 8209   PGC_crtB  GCF_011040475.1_ASM1104047v1_2348
# 8614   PGC_tspO  GCF_011040475.1_ASM1104047v1_2347
# 10016  PGC_crtE  GCF_011040475.1_ASM1104047v1_2344
# 12628  PGC_bchZ  GCF_011040475.1_ASM1104047v1_2339
# Gene PGC_bchE found in genome GCF_003254375.1_ASM325437v1 at position 3596 with nearby genes:
#        hit_gene                    prot_id_unique
# 3235   PGC_bchZ  GCF_003254375.1_ASM325437v1_3600
# 13347  PGC_crtD  GCF_003254375.1_ASM325437v1_3594
# 13501  PGC_crtC  GCF_003254375.1_ASM325437v1_3593
# 13502  PGC_bchC  GCF_003254375.1_ASM325437v1_3597
# 13503  PGC_bchX  GCF_003254375.1_ASM325437v1_3598
# 13504  PGC_bchY  GCF_003254375.1_ASM325437v1_3599
# 15168  PGC_crtE  GCF_003254375.1_ASM325437v1_3595
# Gene PGC_bchE found in genome GCF_009363575.1_ASM936357v1 at position 3655 with nearby genes:
#        hit_gene                    prot_id_unique
# 3643   PGC_bchY  GCF_009363575.1_ASM936357v1_3658
# 3646   PGC_bchX  GCF_009363575.1_ASM936357v1_3657
# 3652   PGC_tspO  GCF_009363575.1_ASM936357v1_3651
# 4514   PGC_bchZ  GCF_009363575.1_ASM936357v1_3659
# 5713   PGC_crtC  GCF_009363575.1_ASM936357v1_3652
# 5747   PGC_bchC  GCF_009363575.1_ASM936357v1_3656
# 7231   PGC_crtD  GCF_009363575.1_ASM936357v1_3653
# 10141  PGC_crtB  GCF_009363575.1_ASM936357v1_3650
# 14199  PGC_crtE  GCF_009363575.1_ASM936357v1_3654
# Gene PGC_bchE found in genome GCF_018687475.1_ASM1868747v1 at position 1387 with nearby genes:
#       hit_gene                     prot_id_unique
# 4026  PGC_bchD  GCF_018687475.1_ASM1868747v1_1390
# 4031  PGC_bchX  GCF_018687475.1_ASM1868747v1_1385
# 4035  PGC_bchY  GCF_018687475.1_ASM1868747v1_1384
# 4036  PGC_bchZ  GCF_018687475.1_ASM1868747v1_1383
# 4259  PGC_bchC  GCF_018687475.1_ASM1868747v1_1386
# 5222  PGC_crtE  GCF_018687475.1_ASM1868747v1_1388
# 8060  PGC_bchO  GCF_018687475.1_ASM1868747v1_1389
# 8314  PGC_bchI  GCF_018687475.1_ASM1868747v1_1391
# Gene PGC_bchE found in genome GCF_030252425.1_ASM3025242v1 at position 830 with nearby genes:
#       hit_gene                    prot_id_unique
# 3333  PGC_bchZ  GCF_030252425.1_ASM3025242v1_834
# 3334  PGC_bchC  GCF_030252425.1_ASM3025242v1_831
# 3336  PGC_crtE  GCF_030252425.1_ASM3025242v1_829
# 4254  PGC_crtC  GCF_030252425.1_ASM3025242v1_827
# 4915  PGC_crtD  GCF_030252425.1_ASM3025242v1_828
# 6402  PGC_bchX  GCF_030252425.1_ASM3025242v1_832
# 8718  PGC_bchY  GCF_030252425.1_ASM3025242v1_833
# Gene PGC_bchE found in genome GCF_005311585.1_ASM531158v1 at position 973 with nearby genes:
#        hit_gene                   prot_id_unique
# 3842   PGC_crtE  GCF_005311585.1_ASM531158v1_972
# 6512   PGC_crtC  GCF_005311585.1_ASM531158v1_970
# 6520   PGC_tspO  GCF_005311585.1_ASM531158v1_969
# 8154   PGC_crtB  GCF_005311585.1_ASM531158v1_968
# ...
# 4814   PGC_bchY  GCF_019623905.1_ASM1962390v1_3260
# 6780   PGC_crtD  GCF_019623905.1_ASM1962390v1_3255
# 9321   PGC_crtB  GCF_019623905.1_ASM1962390v1_3252
# 11583  PGC_tspO  GCF_019623905.1_ASM1962390v1_3253
# 12163  PGC_crtC  GCF_019623905.1_ASM1962390v1_3254
# 12165  PGC_crtE  GCF_019623905.1_ASM1962390v1_3256
# 12170  PGC_bchX  GCF_019623905.1_ASM1962390v1_3259
# 14829  PGC_bchZ  GCF_019623905.1_ASM1962390v1_3261
# Gene PGC_bchE found in genome GCF_014117445.1_ASM1411744v1 at position 1136 with nearby genes:
#        hit_gene                     prot_id_unique
# 3366   PGC_bchY  GCF_014117445.1_ASM1411744v1_1139
# 3927   PGC_bchZ  GCF_014117445.1_ASM1411744v1_1140
# 5047   PGC_crtD  GCF_014117445.1_ASM1411744v1_1135
# 6055   PGC_bchC  GCF_014117445.1_ASM1411744v1_1137
# 7376   PGC_crtC  GCF_014117445.1_ASM1411744v1_1134
# 9410   PGC_bchO  GCF_014117445.1_ASM1411744v1_1132
# 10090  PGC_bchX  GCF_014117445.1_ASM1411744v1_1138
# Gene PGC_bchE found in genome GCF_001886735.1_ASM188673v1 at position 3885 with nearby genes:
#        hit_gene                    prot_id_unique
# 6406   PGC_tspO  GCF_001886735.1_ASM188673v1_3889
# 7581   PGC_bchC  GCF_001886735.1_ASM188673v1_3884
# 10532  PGC_bchY  GCF_001886735.1_ASM188673v1_3882
# 14017  PGC_bchZ  GCF_001886735.1_ASM188673v1_3881
# 14019  PGC_bchX  GCF_001886735.1_ASM188673v1_3883
# 14020  PGC_crtE  GCF_001886735.1_ASM188673v1_3886
# 14023  PGC_crtC  GCF_001886735.1_ASM188673v1_3888
# 14024  PGC_crtB  GCF_001886735.1_ASM188673v1_3890
# Gene PGC_bchE found in genome GCF_030062705.1_ASM3006270v1 at position 3066 with nearby genes:
#        hit_gene                     prot_id_unique
# 3600   PGC_bchY  GCF_030062705.1_ASM3006270v1_3069
# 4028   PGC_bchX  GCF_030062705.1_ASM3006270v1_3068
# 4927   PGC_bchZ  GCF_030062705.1_ASM3006270v1_3070
# 6864   PGC_bchC  GCF_030062705.1_ASM3006270v1_3067
# 12963  PGC_crtC  GCF_030062705.1_ASM3006270v1_3063
# 12964  PGC_crtD  GCF_030062705.1_ASM3006270v1_3064
# 12966  PGC_crtE  GCF_030062705.1_ASM3006270v1_3065
# Gene PGC_bchE found in genome GCF_000018145.1_ASM1814v1 at position 3575 with nearby genes:
#        hit_gene                  prot_id_unique
# 3420   PGC_crtD  GCF_000018145.1_ASM1814v1_3573
# 3672   PGC_bchY  GCF_000018145.1_ASM1814v1_3578
# 5290   PGC_bchC  GCF_000018145.1_ASM1814v1_3576
# 5294   PGC_crtE  GCF_000018145.1_ASM1814v1_3574
# 5297   PGC_crtC  GCF_000018145.1_ASM1814v1_3572
# 5306   PGC_tspO  GCF_000018145.1_ASM1814v1_3570
# 9735   PGC_bchX  GCF_000018145.1_ASM1814v1_3577
# 14722  PGC_bchZ  GCF_000018145.1_ASM1814v1_3579
# Gene PGC_bchE found in genome GCF_014622665.1_ASM1462266v1 at position 720 with nearby genes:
#        hit_gene                    prot_id_unique
# 3426   PGC_crtC  GCF_014622665.1_ASM1462266v1_717
# 3675   PGC_crtD  GCF_014622665.1_ASM1462266v1_718
# 7953   PGC_tspO  GCF_014622665.1_ASM1462266v1_716
# 11195  PGC_crtB  GCF_014622665.1_ASM1462266v1_715
# 14525  PGC_crtE  GCF_014622665.1_ASM1462266v1_719
# 14527  PGC_bchC  GCF_014622665.1_ASM1462266v1_721
# 14528  PGC_bchX  GCF_014622665.1_ASM1462266v1_722
# 14531  PGC_bchY  GCF_014622665.1_ASM1462266v1_723
# 14533  PGC_bchZ  GCF_014622665.1_ASM1462266v1_724
# Gene PGC_bchE found in genome GCF_022410435.1_ASM2241043v1 at position 3428 with nearby genes:
#        hit_gene                     prot_id_unique
# 4413   PGC_bchY  GCF_022410435.1_ASM2241043v1_3431
# 4415   PGC_bchX  GCF_022410435.1_ASM2241043v1_3430
# 5799   PGC_crtD  GCF_022410435.1_ASM2241043v1_3426
# 6060   PGC_crtE  GCF_022410435.1_ASM2241043v1_3427
# 7909   PGC_bchC  GCF_022410435.1_ASM2241043v1_3429
# 8421   PGC_bchZ  GCF_022410435.1_ASM2241043v1_3432
# 14728  PGC_crtC  GCF_022410435.1_ASM2241043v1_3425
# Gene PGC_bchE found in genome GCF_000014045.1_ASM1404v1 at position 106 with nearby genes:
#        hit_gene                 prot_id_unique
# 6230   PGC_crtE  GCF_000014045.1_ASM1404v1_107
# 10673  PGC_crtC  GCF_000014045.1_ASM1404v1_109
# 10884  PGC_bchC  GCF_000014045.1_ASM1404v1_105
# 11633  PGC_crtD  GCF_000014045.1_ASM1404v1_108
# 14049  PGC_bchZ  GCF_000014045.1_ASM1404v1_101
# 14052  PGC_bchY  GCF_000014045.1_ASM1404v1_102
# 14054  PGC_bchX  GCF_000014045.1_ASM1404v1_104
# 14055  PGC_tspO  GCF_000014045.1_ASM1404v1_111
# Gene PGC_bchE found in genome GCF_000973625.1_ASM97362v1 at position 1355 with nearby genes:
#        hit_gene                   prot_id_unique
# 4428   PGC_bchX  GCF_000973625.1_ASM97362v1_1353
# 4717   PGC_bchO  GCF_000973625.1_ASM97362v1_1357
# 10722  PGC_bchY  GCF_000973625.1_ASM97362v1_1352
# 10727  PGC_bchC  GCF_000973625.1_ASM97362v1_1354
# 10728  PGC_crtE  GCF_000973625.1_ASM97362v1_1356
# 10730  PGC_bchD  GCF_000973625.1_ASM97362v1_1358
# 10731  PGC_bchI  GCF_000973625.1_ASM97362v1_1359
# Gene PGC_bchE found in genome GCF_022227035.1_ASM2222703v1 at position 1918 with nearby genes:
#        hit_gene                     prot_id_unique
# 4538   PGC_crtC  GCF_022227035.1_ASM2222703v1_1921
# 4541   PGC_crtE  GCF_022227035.1_ASM2222703v1_1919
# 4547   PGC_bchC  GCF_022227035.1_ASM2222703v1_1917
# 6577   PGC_bchX  GCF_022227035.1_ASM2222703v1_1916
# 7297   PGC_bchZ  GCF_022227035.1_ASM2222703v1_1914
# 7493   PGC_bchY  GCF_022227035.1_ASM2222703v1_1915
# 10115  PGC_crtD  GCF_022227035.1_ASM2222703v1_1920
# Gene PGC_bchE found in genome GCF_001632845.1_ASM163284v1 at position 3063 with nearby genes:
#        hit_gene                    prot_id_unique
# 4178   PGC_crtB  GCF_001632845.1_ASM163284v1_3067
# 4917   PGC_crtD  GCF_001632845.1_ASM163284v1_3065
# 5219   PGC_crtE  GCF_001632845.1_ASM163284v1_3064
# 7213   PGC_bchX  GCF_001632845.1_ASM163284v1_3061
# 9911   PGC_bchZ  GCF_001632845.1_ASM163284v1_3059
# 12139  PGC_crtC  GCF_001632845.1_ASM163284v1_3066
# 13408  PGC_bchY  GCF_001632845.1_ASM163284v1_3060
# 14306  PGC_bchC  GCF_001632845.1_ASM163284v1_3062
# Gene PGC_bchE found in genome GCF_005860795.2_ASM586079v2 at position 455 with nearby genes:
#        hit_gene                   prot_id_unique
# 5710   PGC_bchZ  GCF_005860795.2_ASM586079v2_459
# 6282   PGC_bchY  GCF_005860795.2_ASM586079v2_458
# 6572   PGC_bchC  GCF_005860795.2_ASM586079v2_456
# 6835   PGC_crtE  GCF_005860795.2_ASM586079v2_454
# 8832   PGC_crtB  GCF_005860795.2_ASM586079v2_450
# 9590   PGC_crtC  GCF_005860795.2_ASM586079v2_452
# 10126  PGC_bchX  GCF_005860795.2_ASM586079v2_457
# 15145  PGC_crtD  GCF_005860795.2_ASM586079v2_453
# Gene PGC_bchE found in genome GCF_002158905.1_ASM215890v1 at position 3639 with nearby genes:
#        hit_gene                    prot_id_unique
# 3524   PGC_bchC  GCF_002158905.1_ASM215890v1_3640
# 4082   PGC_crtE  GCF_002158905.1_ASM215890v1_3638
# 4987   PGC_bchZ  GCF_002158905.1_ASM215890v1_3643
# 12675  PGC_crtC  GCF_002158905.1_ASM215890v1_3636
# 12678  PGC_crtD  GCF_002158905.1_ASM215890v1_3637
# 12683  PGC_bchX  GCF_002158905.1_ASM215890v1_3641
# 12684  PGC_bchY  GCF_002158905.1_ASM215890v1_3642
# Gene PGC_bchE found in genome GCF_013307245.1_ASM1330724v1 at position 676 with nearby genes:
#        hit_gene                    prot_id_unique
# 3527   PGC_bchD  GCF_013307245.1_ASM1330724v1_680
# 6531   PGC_bchX  GCF_013307245.1_ASM1330724v1_674
# 10434  PGC_bchC  GCF_013307245.1_ASM1330724v1_675
# 12380  PGC_bchO  GCF_013307245.1_ASM1330724v1_678
# 12653  PGC_bchZ  GCF_013307245.1_ASM1330724v1_672
# 14778  PGC_bchY  GCF_013307245.1_ASM1330724v1_673
# 14782  PGC_crtE  GCF_013307245.1_ASM1330724v1_677
# 14783  PGC_bchI  GCF_013307245.1_ASM1330724v1_681
# Gene PGC_bchE found in genome GCF_003031265.1_ASM303126v1 at position 1500 with nearby genes:
#       hit_gene                    prot_id_unique
# 6456  PGC_bchC  GCF_003031265.1_ASM303126v1_1501
# 6481  PGC_bchX  GCF_003031265.1_ASM303126v1_1502
# 7309  PGC_bchY  GCF_003031265.1_ASM303126v1_1503
# 7531  PGC_crtD  GCF_003031265.1_ASM303126v1_1498
# 7724  PGC_bchZ  GCF_003031265.1_ASM303126v1_1504
# 7747  PGC_crtE  GCF_003031265.1_ASM303126v1_1499
# 8083  PGC_crtC  GCF_003031265.1_ASM303126v1_1497
# Gene PGC_bchE found in genome GCF_000016185.1_ASM1618v1 at position 2004 with nearby genes:
#        hit_gene                  prot_id_unique
# 4293   PGC_crtC  GCF_000016185.1_ASM1618v1_2001
# 7103   PGC_bchX  GCF_000016185.1_ASM1618v1_2006
# 8541   PGC_bchC  GCF_000016185.1_ASM1618v1_2005
# 8741   PGC_bchZ  GCF_000016185.1_ASM1618v1_2008
# 9004   PGC_crtD  GCF_000016185.1_ASM1618v1_2002
# 9150   PGC_bchY  GCF_000016185.1_ASM1618v1_2007
# 13156  PGC_crtE  GCF_000016185.1_ASM1618v1_2003
# Gene PGC_bchE found in genome GCF_023380025.1_ASM2338002v1 at position 2709 with nearby genes:
#        hit_gene                     prot_id_unique
# 3910   PGC_bchO  GCF_023380025.1_ASM2338002v1_2713
# 3912   PGC_crtC  GCF_023380025.1_ASM2338002v1_2711
# 3914   PGC_bchX  GCF_023380025.1_ASM2338002v1_2707
# 4580   PGC_bchY  GCF_023380025.1_ASM2338002v1_2706
# 6304   PGC_bchZ  GCF_023380025.1_ASM2338002v1_2705
# 12997  PGC_crtD  GCF_023380025.1_ASM2338002v1_2710
# 13047  PGC_bchC  GCF_023380025.1_ASM2338002v1_2708
# 13139  PGC_bchD  GCF_023380025.1_ASM2338002v1_2714
# Gene PGC_bchE found in genome GCF_001713355.1_ASM171335v1 at position 2417 with nearby genes:
#        hit_gene                    prot_id_unique
# 6943   PGC_crtC  GCF_001713355.1_ASM171335v1_2415
# 10346  PGC_bchC  GCF_001713355.1_ASM171335v1_2418
# 13058  PGC_bchX  GCF_001713355.1_ASM171335v1_2419
# 13414  PGC_crtB  GCF_001713355.1_ASM171335v1_2412
# 13415  PGC_bchO  GCF_001713355.1_ASM171335v1_2413
# 13418  PGC_crtE  GCF_001713355.1_ASM171335v1_2416
# 13421  PGC_bchY  GCF_001713355.1_ASM171335v1_2420
# 14508  PGC_bchZ  GCF_001713355.1_ASM171335v1_2421
# Gene PGC_bchE found in genome GCF_000757795.1_ASM75779v1 at position 2930 with nearby genes:
#        hit_gene                   prot_id_unique
# 3728   PGC_crtD  GCF_000757795.1_ASM75779v1_2932
# 6592   PGC_bchX  GCF_000757795.1_ASM75779v1_2928
# 7241   PGC_crtC  GCF_000757795.1_ASM75779v1_2933
# 8065   PGC_crtE  GCF_000757795.1_ASM75779v1_2931
# 8593   PGC_bchZ  GCF_000757795.1_ASM75779v1_2926
# 9605   PGC_bchY  GCF_000757795.1_ASM75779v1_2927
# 12491  PGC_bchC  GCF_000757795.1_ASM75779v1_2929
# Gene PGC_bchE found in genome GCF_000327045.1_ASM32704v1 at position 2936 with nearby genes:
#       hit_gene                   prot_id_unique
# 3752  PGC_crtD  GCF_000327045.1_ASM32704v1_2938
# 3759  PGC_bchX  GCF_000327045.1_ASM32704v1_2934
# 3761  PGC_bchY  GCF_000327045.1_ASM32704v1_2933
# 3762  PGC_bchZ  GCF_000327045.1_ASM32704v1_2932
# 4205  PGC_bchC  GCF_000327045.1_ASM32704v1_2935
# 4603  PGC_crtC  GCF_000327045.1_ASM32704v1_2939
# 5188  PGC_crtE  GCF_000327045.1_ASM32704v1_2937
# 5377  PGC_crtI  GCF_000327045.1_ASM32704v1_2941
# 7749  PGC_crtB  GCF_000327045.1_ASM32704v1_2940
# Gene PGC_bchE found in genome GCF_001412575.1_ASM141257v1 at position 953 with nearby genes:
#        hit_gene                   prot_id_unique
# 10609  PGC_bchZ  GCF_001412575.1_ASM141257v1_957
# 11524  PGC_crtE  GCF_001412575.1_ASM141257v1_952
# 11528  PGC_bchX  GCF_001412575.1_ASM141257v1_955
# 11529  PGC_bchY  GCF_001412575.1_ASM141257v1_956
# 12545  PGC_bchC  GCF_001412575.1_ASM141257v1_954
# Gene PGC_bchE found in genome GCF_028621955.1_ASM2862195v1 at position 334 with nearby genes:
#        hit_gene                    prot_id_unique
# 7095   PGC_crtD  GCF_028621955.1_ASM2862195v1_333
# 8402   PGC_crtC  GCF_028621955.1_ASM2862195v1_332
# 8414   PGC_bchX  GCF_028621955.1_ASM2862195v1_336
# 9890   PGC_bchC  GCF_028621955.1_ASM2862195v1_335
# 11394  PGC_bchZ  GCF_028621955.1_ASM2862195v1_338
# 12606  PGC_bchY  GCF_028621955.1_ASM2862195v1_337
# 12688  PGC_bchO  GCF_028621955.1_ASM2862195v1_329
# Gene PGC_bchE found in genome GCF_002407205.1_ASM240720v1 at position 2156 with nearby genes:
#        hit_gene                    prot_id_unique
# 11049  PGC_crtE  GCF_002407205.1_ASM240720v1_2157
# 13460  PGC_crtB  GCF_002407205.1_ASM240720v1_2161
# 15157  PGC_bchZ  GCF_002407205.1_ASM240720v1_2152
# 15158  PGC_bchY  GCF_002407205.1_ASM240720v1_2153
# 15160  PGC_bchX  GCF_002407205.1_ASM240720v1_2154
# 15162  PGC_bchC  GCF_002407205.1_ASM240720v1_2155
# 15164  PGC_crtD  GCF_002407205.1_ASM240720v1_2158
# 15167  PGC_crtC  GCF_002407205.1_ASM240720v1_2159
# 15170  PGC_tspO  GCF_002407205.1_ASM240720v1_2160
# Gene PGC_bchE found in genome GCF_023558355.1_ASM2355835v1 at position 3574 with nearby genes:
#        hit_gene                     prot_id_unique
# 7063   PGC_bchZ  GCF_023558355.1_ASM2355835v1_3578
# 7253   PGC_crtD  GCF_023558355.1_ASM2355835v1_3572
# 7736   PGC_bchX  GCF_023558355.1_ASM2355835v1_3576
# 9507   PGC_crtE  GCF_023558355.1_ASM2355835v1_3573
# 9625   PGC_bchY  GCF_023558355.1_ASM2355835v1_3577
# 11146  PGC_tspO  GCF_023558355.1_ASM2355835v1_3569
# 11187  PGC_bchC  GCF_023558355.1_ASM2355835v1_3575
# 11723  PGC_crtC  GCF_023558355.1_ASM2355835v1_3571
# Gene PGC_bchE found in genome GCF_009650195.1_ASM965019v1 at position 3148 with nearby genes:
#        hit_gene                    prot_id_unique
# 9198   PGC_bchX  GCF_009650195.1_ASM965019v1_3150
# 9775   PGC_crtC  GCF_009650195.1_ASM965019v1_3145
# 10579  PGC_crtB  GCF_009650195.1_ASM965019v1_3143
# 10581  PGC_crtD  GCF_009650195.1_ASM965019v1_3146
# 10582  PGC_crtE  GCF_009650195.1_ASM965019v1_3147
# 10589  PGC_bchY  GCF_009650195.1_ASM965019v1_3151
# 10590  PGC_bchZ  GCF_009650195.1_ASM965019v1_3152
# 13876  PGC_bchC  GCF_009650195.1_ASM965019v1_3149
# Gene PGC_bchE found in genome GCF_002073975.1_ASM207397v1 at position 3519 with nearby genes:
#        hit_gene                    prot_id_unique
# 8702   PGC_crtE  GCF_002073975.1_ASM207397v1_3520
# 9295   PGC_bchZ  GCF_002073975.1_ASM207397v1_3514
# 10744  PGC_bchY  GCF_002073975.1_ASM207397v1_3515
# 13167  PGC_bchX  GCF_002073975.1_ASM207397v1_3517
# 13830  PGC_bchC  GCF_002073975.1_ASM207397v1_3518
# 13990  PGC_crtD  GCF_002073975.1_ASM207397v1_3521
# 13991  PGC_crtC  GCF_002073975.1_ASM207397v1_3522
# Gene PGC_bchE found in genome GCF_009859815.1_ASM985981v1 at position 2514 with nearby genes:
#        hit_gene                    prot_id_unique
# 5056   PGC_bchZ  GCF_009859815.1_ASM985981v1_2518
# 5164   PGC_crtE  GCF_009859815.1_ASM985981v1_2513
# 7811   PGC_bchC  GCF_009859815.1_ASM985981v1_2515
# 8290   PGC_bchY  GCF_009859815.1_ASM985981v1_2517
# 11921  PGC_bchX  GCF_009859815.1_ASM985981v1_2516
# Gene PGC_bchE found in genome GCF_003952725.1_ASM395272v1 at position 956 with nearby genes:
#        hit_gene                   prot_id_unique
# 4258   PGC_crtI  GCF_003952725.1_ASM395272v1_961
# 10112  PGC_bchY  GCF_003952725.1_ASM395272v1_953
# 10484  PGC_crtD  GCF_003952725.1_ASM395272v1_958
# 10753  PGC_bchC  GCF_003952725.1_ASM395272v1_955
# 12884  PGC_crtB  GCF_003952725.1_ASM395272v1_960
# 15196  PGC_bchZ  GCF_003952725.1_ASM395272v1_952
# 15197  PGC_bchX  GCF_003952725.1_ASM395272v1_954
# 15198  PGC_crtE  GCF_003952725.1_ASM395272v1_957
# 15199  PGC_crtC  GCF_003952725.1_ASM395272v1_959
# Gene PGC_bchE found in genome GCF_025141175.1_ASM2514117v1 at position 637 with nearby genes:
#        hit_gene                    prot_id_unique
# 4496   PGC_crtE  GCF_025141175.1_ASM2514117v1_636
# 9315   PGC_bchC  GCF_025141175.1_ASM2514117v1_638
# 9661   PGC_bchY  GCF_025141175.1_ASM2514117v1_640
# 12288  PGC_crtC  GCF_025141175.1_ASM2514117v1_634
# 12352  PGC_crtD  GCF_025141175.1_ASM2514117v1_635
# 12353  PGC_bchX  GCF_025141175.1_ASM2514117v1_639
# 12354  PGC_bchZ  GCF_025141175.1_ASM2514117v1_641
# Gene PGC_bchE found in genome GCF_009363615.1_ASM936361v1 at position 1985 with nearby genes:
#        hit_gene                    prot_id_unique
# 6256   PGC_bchX  GCF_009363615.1_ASM936361v1_1983
# 6636   PGC_crtE  GCF_009363615.1_ASM936361v1_1986
# 8134   PGC_crtC  GCF_009363615.1_ASM936361v1_1988
# 8562   PGC_bchY  GCF_009363615.1_ASM936361v1_1982
# 9528   PGC_bchZ  GCF_009363615.1_ASM936361v1_1981
# 9766   PGC_tspO  GCF_009363615.1_ASM936361v1_1989
# 9768   PGC_crtB  GCF_009363615.1_ASM936361v1_1990
# 9820   PGC_crtD  GCF_009363615.1_ASM936361v1_1987
# 10225  PGC_bchC  GCF_009363615.1_ASM936361v1_1984
# Gene PGC_bchE found in genome GCF_014495845.1_ASM1449584v1 at position 2426 with nearby genes:
#        hit_gene                     prot_id_unique
# 6434   PGC_crtC  GCF_014495845.1_ASM1449584v1_2423
# 6960   PGC_crtE  GCF_014495845.1_ASM1449584v1_2425
# 10481  PGC_bchZ  GCF_014495845.1_ASM1449584v1_2430
# 14230  PGC_crtB  GCF_014495845.1_ASM1449584v1_2421
# 14231  PGC_crtD  GCF_014495845.1_ASM1449584v1_2424
# 14235  PGC_bchX  GCF_014495845.1_ASM1449584v1_2428
# 14237  PGC_bchY  GCF_014495845.1_ASM1449584v1_2429
# 1
# 127

# %%
# Vérification de la localisation intra ou extra cluster de tspO, bchO, crtE, bchE

output_silix = pd.read_csv("../results/lists_PGC/output_silix_fullname_v1.csv")
unique_genome_silix = output_silix["genome"].dropna().unique()
numbers=[]

genes_of_interest = ["PGC_tspO", "PGC_bchO", "PGC_crtE", "PGC_bchE"]
gene_counts = {gene: {'with_nearby_gene': 0, 'without_nearby_gene': 0} for gene in genes_of_interest}

for genome in unique_genome_silix:
    # Filter the dataframe to only include rows where the genome column matches the current genome
    filtered_df = output_silix[(output_silix["genome"] == genome) & output_silix["hit_gene"].notna()]

    # Extract the prot_id_unique column from the filtered dataframe
    gene_number = filtered_df["prot_id_unique"]

    # Remove the prefix "genome_" from each element in the gene_number series
    gene_number = gene_number.str.replace(f"{genome}_", "", regex=False)

    # Convert the gene_number series to integers
    gene_number = gene_number.astype(int)

    # Search for the genes of interest in the filtered dataframe
    for gene in genes_of_interest:
        gene_match = filtered_df[filtered_df['hit_gene'] == gene]
        if not gene_match.empty:
            # Get the position of the gene
            gene_position = gene_match.iloc[0]['prot_id_unique']
            gene_position = int(gene_position.replace(f"{genome}_", ""))

            # Get the indices of the genes within the range of +5 to -5
            nearby_indices = (gene_number >= gene_position - 5) & (gene_number <= gene_position + 5)

            # Get the nearby genes
            nearby_genes = filtered_df[nearby_indices]

            # Remove the gene in question from the nearby genes
            nearby_genes = nearby_genes[nearby_genes['hit_gene'] != gene]

            # Update the gene counts
            if not nearby_genes.empty:
                gene_counts[gene]['with_nearby_gene'] += 1
            else:
                gene_counts[gene]['without_nearby_gene'] += 1

# Create a dataframe from the gene counts
gene_counts_df = pd.DataFrame(gene_counts).T.reset_index().rename(columns={'index': 'gene'})

# Print the gene counts dataframe
print(gene_counts_df)
# Out:
#        gene  with_nearby_gene  without_nearby_gene
# 0  PGC_tspO               197                   31
# 1  PGC_bchO               236                    5
# 2  PGC_crtE               199                   46
# 3  PGC_bchE               127                    1

# %%
# Le but ici est de récupérer les grandes familles connus mais non présentes dans PGCfinder pour tenter de les incorporer au modèl
famille_counts = output_silix["Family"].value_counts()
grandes_familles = output_silix[output_silix["Family"].isin(famille_counts[famille_counts > 100].index)]
petites_familles = output_silix[output_silix["Family"].isin(famille_counts[famille_counts < 100].index)]
print(grandes_familles["gene"].value_counts())

print(petites_familles["gene"].value_counts().head(30))
# Out:
# gene
# no_gene_name    4209
# ppsR             273
# pufB             260
# crtI             248
# bchF             244
# puhA             243
# chlG             243
# pufA             243
# bchY             243
# bchZ             240
# bchL             238
# pufM             237
# pufL             237
# bchC             236
# bchM             235
# puhB             235
# bchB             234
# puhC             228
# puhE             227
# acsF             224
# bchI             213
# hemA             176
# pufC             158
# crtC              11
# tspO               9
# cycA               8
# bchH               2
# bioF               1
# bchD               1
# Name: count, dtype: int64
# gene
# no_gene_name    4539
# dxs               77
# idi               71
# pufQ              53
# crtY              48
# hemC              44
# bchJ              44
# queA              41
# coaD              40
# bchE              34
# hemE              27
# pufX              25
# hemF              24
# purL              21
# pyk               19
# ispH              17
# ykgO              16
# clpA              16
# ureC              15
# gnd               15
# efp               15
# ftsY              15
# pgl               15
# ureG              15
# clpS              14
# dinB              14
# epmA              13
# dapF              13
# mtaB              13
# pufA              13
# Name: count, dtype: int64

# %%
print(grandes_familles["hit_gene"].value_counts())
# Out:
# hit_gene
# PGC_ppsR     277
# PGC_bchL     245
# PGC_pufM     245
# PGC_bchX     245
# PGC_lhaA     245
# PGC_puhA     245
# PGC_bchF     245
# PGC_pufL     245
# PGC_bchP     244
# PGC_puhB     244
# PGC_bchY     244
# PGC_bchG     244
# PGC_crtE     243
# PGC_bchB     242
# PGC_crtC     242
# PGC_bchN     242
# PGC_bchC     242
# PGC_crtB     242
# PGC_bchZ     241
# PGC_bchM     241
# PGC_bchH     240
# PGC_crtD     240
# PGC_bchD     238
# PGC_bchO     238
# PGC_puhE     237
# PGC_crtI     237
# PGC_tspO     236
# PGC_bchI     229
# PGC_acsF     225
# PGC_pucC2    222
# PGC_bchE     128
# PGC_crtF     114
# Name: count, dtype: int64

# %%
# Ici je peux observer les plus grandes familes présentes dans mon clustering avec SiliX, et en observant le fichier, savoir quelles gènes sont hit (voir carnet)
print(grandes_familles["Family"].value_counts())
# Out:
# Family
# FAM000014    490
# FAM000038    477
# FAM000012    467
# FAM000031    301
# FAM000022    278
# FAM000030    253
# FAM000011    245
# FAM000018    245
# FAM000029    245
# FAM000028    245
# FAM000026    244
# FAM000034    244
# FAM000010    244
# FAM000027    244
# FAM000037    243
# FAM000039    242
# FAM000016    242
# FAM000017    242
# FAM000036    242
# FAM000035    242
# FAM000042    242
# FAM000013    241
# FAM000033    241
# FAM000015    240
# FAM000047    238
# FAM000043    238
# FAM000006    237
# FAM000009    237
# FAM000025    236
# FAM000048    229
# FAM000007    225
# FAM000008    202
# FAM000005    177
# FAM000058    164
# FAM000019    154
# FAM000024    145
# FAM000023    128
# FAM000040    107
# Name: count, dtype: int64

# %%
df_clean["PGC replicon type"].value_counts()
# Out:
# PGC replicon type
# chromosome            243
# plasmid                 7
# plasmid/chromosome      1
# chromosome/plasmid      1
# unknown                 1
# Name: count, dtype: int64

# %%
# Search for 'plasmid' in the 'Replicons' column
mask_plasmid = df_clean['Replicons'].str.contains('plasmid', na=False)
mask_chromosome = df_clean['Replicons'].str.contains('chromosome', na=False)
mask_plasmid_and_chromosome = df_clean['Replicons'].str.contains('plasmid', na=False) & ~df_clean['Replicons'].str.contains('chromosome', na=False)
mask_unknown = df_clean['Replicons'].str.contains('unknown', na=False) | df_clean['Replicons'].str.contains('Unknown', na=False)

# Count the number of times 'plasmid' appears
print(mask_plasmid.sum())
print(mask_chromosome.sum())
print(mask_plasmid_and_chromosome.sum())
print(mask_unknown.sum())
# Out:
# 10413
# 19580
# 0
# 3

# %%
count_plasmid = df_clean['Replicons'].str.count('plasmid', flags=re.IGNORECASE).sum()
count_chromosome = df_clean['Replicons'].str.count('chromosome', flags=re.IGNORECASE).sum()

# Ici je compte le nombre d'occurence de "plamsid" et "chromosome" pour avoir un avis sur la distribution de ceux-ci au travers du génomes
print(count_plasmid)
print(count_chromosome)
# Out:
# 28844.0
# 21530.0

# %%
# Bryant + PGCfinder
# Df contenant les lignes faisant parties d'une espèce ayant au moins un phototrophes d'après Bryant et ayant un pgc prédit par PGCfinder
df_clean_phototroph_genus = df_clean[df_clean["Phototrophic group by genus"].notnull() & df_clean["number of PGC"].notnull()]
# Df contenant les lignes ayant une espèce d'après Bryant et ayant un pgc prédit par PGCfinder
df_clean_phototroph = df_clean[df_clean["Phototrophic group"].notnull() & df_clean["number of PGC"].notnull()]
print(df_clean_phototroph_genus["Phototrophic group by genus"].value_counts())
print(df_clean_phototroph["Phototrophic group"].value_counts())
# Out:
# Phototrophic group by genus
# pAAPB    112
# PNSB      45
# AAPB      29
# PSB        7
# Name: count, dtype: int64
# Phototrophic group
# pAAPB    39
# PNSB     22
# AAPB      9
# PSB       6
# Name: count, dtype: int64

# %%
# Bryant - PGCfinder
df_clean_phototroph_genus = df_clean[df_clean["Phototrophic group by genus"].notnull() & ~df_clean["number of PGC"].notnull()]
df_clean_phototroph = df_clean[df_clean["Phototrophic group"].notnull() & ~df_clean["number of PGC"].notnull()]
print(df_clean_phototroph_genus["Phototrophic group by genus"].value_counts())
print(df_clean_phototroph["Phototrophic group"].value_counts())
# Out:
# Phototrophic group by genus
# pAAPB    393
# PNSB      13
# AAPB       9
# Name: count, dtype: int64
# Phototrophic group
# AAPB    1
# Name: count, dtype: int64

# %%
# PGCfinder - Bryant
df_clean_phototroph_genus = df_clean[~df_clean["Phototrophic group by genus"].notnull() & df_clean["number of PGC"].notnull()]
df_clean_phototroph = df_clean[~df_clean["Phototrophic group"].notnull() & df_clean["number of PGC"].notnull()]
print(df_clean_phototroph_genus["PGC replicon type"].value_counts())
print(df_clean_phototroph["PGC replicon type"].value_counts())
# Out:
# PGC replicon type
# chromosome            56
# plasmid                2
# plasmid/chromosome     1
# unknown                1
# Name: count, dtype: int64
# PGC replicon type
# chromosome            171
# plasmid                 4
# plasmid/chromosome      1
# unknown                 1
# Name: count, dtype: int64

# %%
df_clean["order"].value_counts()
# Out:
# order
# Enterobacterales                  8993
# Burkholderiales                   2047
# Pseudomonadales                   1551
# Hyphomicrobiales                  1015
# Moraxellales                       957
# Xanthomonadales                    805
# Pasteurellales                     639
# Vibrionales                        595
# Neisseriales                       401
# Rhodobacterales                    335
# Alteromonadales                    319
# Aeromonadales                      263
# Sphingomonadales                   247
# Thiotrichales                      234
# Rickettsiales                      219
# Legionellales                      186
# Rhodospirillales                   167
# Oceanospirillales                  160
# Caulobacterales                     61
# Chromatiales                        50
# Rhodocyclales                       49
# Nitrosomonadales                    45
# Cellvibrionales                     39
# Methylococcales                     33
# Acidithiobacillales                 17
# Holosporales                         7
# Candidatus Pelagibacterales          7
# Orbales                              7
# Hyphomonadales                       6
# Cardiobacteriales                    5
# Kangiellales                         4
# Acidiferrobacterales                 4
# Ferrovales                           4
# Nevskiales                           4
# Kordiimonadales                      4
# Maricaulales                         4
# Emcibacterales                       3
# Mariprofundales                      2
# Sneathiellales                       2
# Parvularculales                      2
# Immundisolibacterales                1
# Salinisphaerales                     1
# Magnetococcales                      1
# Hydrogenophilales                    1
# Candidatus Comchoanobacterales       1
# Name: count, dtype: int64
